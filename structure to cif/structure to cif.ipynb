# %%
# csv_to_cif.py
import os, ast, json, math
from collections import Counter
import numpy as np
import pandas as pd


def vec_len(v): return float(np.linalg.norm(np.array(v, float)))

def angle_deg(u, v):
    u = np.array(u, float); v = np.array(v, float)
    cosang = float(np.dot(u, v) / (np.linalg.norm(u) * np.linalg.norm(v)))
    cosang = max(-1.0, min(1.0, cosang))
    return float(np.degrees(math.acos(cosang)))

def cart_to_frac(a_vec, b_vec, c_vec, r_cart):
    M = np.column_stack([a_vec, b_vec, c_vec])
    f = np.linalg.solve(M, r_cart)
    return f - np.floor(f)  # wrap to [0,1)


def normalize_space_group(sg):
    if not sg or not isinstance(sg, str): return "P 1"
    return sg.replace("-3", " -3 ").replace(":", " : ").strip()

def make_formula_sum(elements):
    c = Counter(elements)
    return " ".join(f"{el}{c[el]}" for el in sorted(c))


def parse_structure_field(value):
    """
    Parse the 'structure' column: JSON → ast.literal_eval → list/dict
    Returns: list[dict]
    """
    if isinstance(value, (list, dict)):
        s = value
    elif pd.isna(value):
        raise ValueError("structure is NaN")
    else:
        t = str(value).strip()
        try:
            s = json.loads(t)
        except Exception:
            try:
                s = ast.literal_eval(t)
            except Exception as e:
                raise ValueError(f"cannot parse structure: {e}")
    if isinstance(s, dict):
        s = [s]
    if not isinstance(s, list) or not s:
        raise ValueError("parsed structure is neither list nor non-empty list")
    return s


def detect_and_to_angstrom(vec):
    """Convert lattice vector to Å. (If norm < 1e-6, assume meter and divide by 1e-10)"""
    v = np.array(vec, float)
    return v/1e-10 if np.linalg.norm(v) < 1e-6 else v

def detect_pos_and_to_angstrom(pos):
    """Convert atomic position to Å. (If norm < 1e-6, assume meter and divide by 1e-10)"""
    r = np.array(pos, float)
    return r/1e-10 if np.linalg.norm(r) < 1e-6 else r


def build_cif_text(formula_structural, space_group,
                   a_len, b_len, c_len, alpha, beta, gamma, volume,
                   site_rows, atom_types, data_prefix=""):
    lines = []
    lines.append("# generated using pymatgen")
    lines.append(f"data_{data_prefix}{formula_structural}")
    lines.append(f"_symmetry_space_group_name_H-M   '{space_group}'")
    lines.append(f"_cell_length_a   {a_len:.8f}")
    lines.append(f"_cell_length_b   {b_len:.8f}")
    lines.append(f"_cell_length_c   {c_len:.8f}")
    lines.append(f"_cell_angle_alpha   {alpha:.8f}")
    lines.append(f"_cell_angle_beta   {beta:.8f}")
    lines.append(f"_cell_angle_gamma   {gamma:.8f}")
    lines.append(f"_chemical_formula_structural   {formula_structural}")
    lines.append(f"_chemical_formula_sum   '{make_formula_sum(atom_types)}'")
    lines.append(f"_cell_volume   {volume:.8f}")

    lines.append("loop_")
    lines.append(" _symmetry_equiv_pos_site_id")
    lines.append(" _symmetry_equiv_pos_as_xyz")
    lines.append("  1  'x, y, z'")

    lines.append("loop_")
    lines.append(" _atom_type_symbol")
    for el in sorted(set(atom_types)):
        lines.append(f"  {el}")

    lines.append("loop_")
    lines.append(" _atom_site_type_symbol")
    lines.append(" _atom_site_label")
    lines.append(" _atom_site_symmetry_multiplicity")
    lines.append(" _atom_site_fract_x")
    lines.append(" _atom_site_fract_y")
    lines.append(" _atom_site_fract_z")
    lines.append(" _atom_site_occupancy")
    for r in site_rows:
        lines.append(
            f"  {r['type_symbol']}  {r['label']}  {r['mult']}  "
            f"{r['fx']:.8f}  {r['fy']:.8f}  {r['fz']:.8f}  {r['occ']:.0f}"
        )
    return "\n".join(lines) + "\n"


def write_cif_from_row(row, out_dir: str, number: int) -> str:
    s0 = parse_structure_field(row["structure"])[0]
    if "data" not in s0:
        raise ValueError("structure[0] has no 'data'")
    cell = s0["data"]
    for k in ("a", "b", "c", "atoms"):
        if k not in cell:
            raise ValueError(f"cell missing '{k}'")

    atoms = cell["atoms"]

    # Lattice parameters
    a_vec = detect_and_to_angstrom(cell["a"])
    b_vec = detect_and_to_angstrom(cell["b"])
    c_vec = detect_and_to_angstrom(cell["c"])
    a_len, b_len, c_len = vec_len(a_vec), vec_len(b_vec), vec_len(c_vec)
    alpha, beta, gamma = angle_deg(b_vec, c_vec), angle_deg(a_vec, c_vec), angle_deg(a_vec, b_vec)
    volume = float(np.dot(a_vec, np.cross(b_vec, c_vec)))

    # Coordinates → Å → fractional coordinates
    elements, atom_cart = [], []
    for at in atoms:
        if not all(k in at for k in ("x", "y", "z", "element")):
            raise ValueError("atom missing one of x,y,z,element")
        elements.append(at["element"])
        atom_cart.append(detect_pos_and_to_angstrom([at["x"], at["y"], at["z"]]))
    atom_frac = [cart_to_frac(a_vec, b_vec, c_vec, rc) for rc in atom_cart]

    # Site labels
    cnt = Counter(); site_rows = []
    for el, f in zip(elements, atom_frac):
        label = f"{el}{cnt[el]}"; cnt[el] += 1
        site_rows.append({"type_symbol": el, "label": label, "mult": 1,
                          "fx": f[0], "fy": f[1], "fz": f[2], "occ": 1.0})

    formula_structural = (row.get("formula") or "".join(sorted(set(elements)))).strip()
    sg = normalize_space_group(row.get("space_group"))

    cif_text = build_cif_text(
        formula_structural, sg, a_len, b_len, c_len, alpha, beta, gamma, volume,
        site_rows, elements, data_prefix=f"{number}_"
    )

    safe_formula = "".join(ch if ch.isalnum() or ch in "-_." else "_" for ch in formula_structural) or "structure"
    out_path = os.path.join(out_dir, f"{number}_{safe_formula}.cif")
    with open(out_path, "w", encoding="utf-8") as f:
        f.write(cif_text)
    return out_path


def convert_csv_to_cif(csv_path: str, out_dir: str = "result") -> list[str]:
    os.makedirs(out_dir, exist_ok=True)
    df = pd.read_csv(csv_path)

    out_files = []
    skipped = []  # (row_number(2-based), df_index, reason)

    # 🔢 Start numbering from 2 → row 2 (Ni4Ta6) gets number 2
    for row_number, (df_index, row) in enumerate(df.iterrows(), start=2):
        # ✅ If formula is empty, stop immediately (do not record skipped)
        formula_val = row.get("formula")
        if pd.isna(formula_val) or str(formula_val).strip() == "":
            print(f"Stop at row {row_number}: empty 'formula'.")
            break

        # Normal processing: if failed, record in skipped and continue
        try:
            if "structure" not in row or pd.isna(row["structure"]):
                raise ValueError("structure is NaN")
            out_files.append(write_cif_from_row(row, out_dir, number=row_number))
        except Exception as e:
            skipped.append((row_number, df_index, str(e)))
            # keep going (no stop)

    # Save skipped records
    if skipped:
        pd.DataFrame(skipped, columns=["row_number(2-based)", "df_index", "reason"])\
          .to_csv(os.path.join(out_dir, "skipped_rows.csv"), index=False)

    print(f"Done. Created {len(out_files)} CIFs. Skipped {len(skipped)} rows.")
    return out_files


if __name__ == "__main__":
    # Example: your uploaded file name
    csv_path = "1_MatDX_EF.csv"
    files = convert_csv_to_cif(csv_path, out_dir="result")
    for p in files:
        print(" -", p)
# Out:
# Done. Created 4471 CIFs. Skipped 529 rows.
#  - result\2_Ni4Ta6.cif
#  - result\3_Mn4Sb2.cif
#  - result\4_Ir2Na2.cif
#  - result\5_MoSm.cif
#  - result\6_Sn17P12.cif
#  - result\7_Sr6Br4.cif
#  - result\8_Ge4P12.cif
#  - result\9_Mn8Sb.cif
#  - result\10_Ba2Bi3.cif
#  - result\11_Mo3W3.cif
#  - result\12_InSn5.cif
#  - result\13_Ga2Sr.cif
#  - result\14_Pd2Ta2.cif
#  - result\15_CuNb.cif
#  - result\16_Ac4I6.cif
#  - result\17_Fe6Sb18.cif
#  - result\18_InSn5.cif
#  - result\19_In4Sn2.cif
#  - result\20_Sr6Br4.cif
#  - result\21_In2Sn4.cif
#  - result\22_RhGe3.cif
#  - result\23_CuEu.cif
#  - result\24_Cu2Ga2.cif
#  - result\25_Fe4Na8.cif
#  - result\26_PtSm.cif
#  - result\27_Cr4Sr5.cif
#  - result\28_CeSb.cif
#  - result\29_Nb2W6.cif
#  - result\30_In5Br.cif
#  - result\31_CsNi.cif
#  - result\32_In4Br12.cif
#  - result\33_Ir3K.cif
#  - result\34_Nb4W8.cif
#  - result\35_Ag4Sn8.cif
#  - result\36_Nb6Pt2.cif
#  - result\37_AlMn.cif
#  - result\38_SbP.cif
#  - result\39_CrTa3.cif
#  - result\40_Al2Rh.cif
#  - result\41_TaV5.cif
#  - result\42_Au2P.cif
#  - result\43_Ir2Ta4.cif
#  - result\44_NiPt.cif
#  - result\45_CaRh2.cif
#  - result\46_Cr3Sr.cif
#  - result\47_Na2Pt2.cif
#  - result\48_Pb4As2.cif
#  - result\49_Al3Sb5.cif
#  - result\50_Ir16Pd8.cif
#  - result\51_Ag2Br2.cif
#  - result\52_Ca4Ta2.cif
#  - result\53_NiRh.cif
#  - result\54_Ba2Sn6.cif
#  - result\55_AgMn.cif
#  - result\56_CsMn.cif
#  - result\57_Ga2Np.cif
#  - result\58_Na2Pt4.cif
#  - result\59_GaNp.cif
#  - result\60_CuMn3.cif
#  - result\61_NpPd.cif
#  - result\62_FeIr2.cif
#  - result\63_Cr2Sr2.cif
#  - result\64_Ag3Al5.cif
#  - result\65_Al4P2.cif
#  - result\66_CsSb.cif
#  - result\67_Ac3Yb.cif
#  - result\68_FePb3.cif
#  - result\69_FeP.cif
#  - result\70_Al3Nb.cif
#  - result\71_Au6Mn2.cif
#  - result\72_Ni4Ge4.cif
#  - result\73_NiSb2.cif
#  - result\74_SmSb.cif
#  - result\75_Fe8Pt.cif
#  - result\76_RhV.cif
#  - result\77_Au4Mn.cif
#  - result\78_Ni4Sb2.cif
#  - result\79_Ag2Al6.cif
#  - result\80_Ag4Al5.cif
#  - result\81_Mo2As.cif
#  - result\82_Al2Sn6.cif
#  - result\83_IrMn2.cif
#  - result\84_AcMn.cif
#  - result\85_Ni2Sb.cif
#  - result\86_Ni2Sb2.cif
#  - result\87_AuMn3.cif
#  - result\88_Ag2Al2.cif
#  - result\89_Ba2Ge2.cif
#  - result\90_IrSn.cif
#  - result\91_V3Br.cif
#  - result\92_InI.cif
#  - result\93_GaGe.cif
#  - result\94_Al2Pd2.cif
#  - result\95_Cr2W2.cif
#  - result\96_Mn3Sn.cif
#  - result\97_Ag3Al.cif
#  - result\98_Cr3Sn.cif
#  - result\99_Al2Pd2.cif
#  - result\100_Ge3Br.cif
#  - result\101_CrW3.cif
#  - result\102_Cr2Sn2.cif
#  - result\103_Fe2Pt.cif
#  - result\104_KSn2.cif
#  - result\105_Cr3W.cif
#  - result\106_CsV.cif
#  - result\107_Cr2Sn2.cif
#  - result\108_Fe2Pb2.cif
#  - result\109_V2Br2.cif
#  - result\110_Cr4Rh.cif
#  - result\111_AgAl3.cif
#  - result\112_VBr3.cif
#  - result\113_CsV.cif
#  - result\114_CrNb3.cif
#  - result\115_CrRh2.cif
#  - result\116_Ba2Ge2.cif
#  - result\117_Mn2Sn.cif
#  - result\118_CrTa.cif
#  - result\119_IrP.cif
#  - result\120_Cu8Fe16.cif
#  - result\121_Fe12W12.cif
#  - result\122_Na2Pt.cif
#  - result\123_WP.cif
#  - result\124_PbV3.cif
#  - result\125_Nb4I16.cif
#  - result\126_Ta4Ge2.cif
#  - result\127_Ge4As2.cif
#  - result\128_As4Br2.cif
#  - result\129_InPt.cif
#  - result\130_GaP.cif
#  - result\131_NiSn.cif
#  - result\132_Au2In4.cif
#  - result\133_AlNb5.cif
#  - result\134_Au4Sr16.cif
#  - result\135_Pt8Sn4.cif
#  - result\136_Cu6Pt4.cif
#  - result\137_Au3P.cif
#  - result\138_Ge2As4.cif
#  - result\139_NpSb.cif
#  - result\140_CrNb5.cif
#  - result\141_CeBr.cif
#  - result\142_Ce12Ga8.cif
#  - result\143_Ba2Pt2.cif
#  - result\144_CaRh4.cif
#  - result\145_Cu4Fe8.cif
#  - result\146_RbRh.cif
#  - result\147_Cu2Ni26.cif
#  - result\148_CrTh.cif
#  - result\149_PdRh2.cif
#  - result\150_YbP.cif
#  - result\151_Ir2Mo4.cif
#  - result\152_Ni2As6.cif
#  - result\153_Al3V.cif
#  - result\154_Pd2Ta2.cif
#  - result\155_NiAs3.cif
#  - result\156_Cr10Nb6.cif
#  - result\157_Ag3Al4.cif
#  - result\158_Cu2Ge4.cif
#  - result\159_CrMn.cif
#  - result\160_Ba2Pt2.cif
#  - result\161_Ni2Ta4.cif
#  - result\162_FeAs3.cif
#  - result\163_As3Br.cif
#  - result\164_Mo3P.cif
#  - result\165_Ni2Sn.cif
#  - result\166_K4Sn2.cif
#  - result\167_Al3P.cif
#  - result\168_Fe8Mo16.cif
#  - result\169_Cu3Ta.cif
#  - result\170_AlTa2.cif
#  - result\171_Cu5Pt5.cif
#  - result\172_CuTh.cif
#  - result\173_Ba2V.cif
#  - result\174_PbSr7.cif
#  - result\175_Fe3As.cif
#  - result\176_In3K.cif
#  - result\177_Au3Sr.cif
#  - result\178_SrW2.cif
#  - result\179_Al2Rh.cif
#  - result\180_Pd2Rh2.cif
#  - result\181_WSb.cif
#  - result\182_Cu6Ni2.cif
#  - result\183_AgP3.cif
#  - result\184_W3Sb.cif
#  - result\185_AgSn.cif
#  - result\186_Ir2Mo6.cif
#  - result\187_Ta2Ge2.cif
#  - result\188_BiBr.cif
#  - result\189_CaW2.cif
#  - result\190_CrCu.cif
#  - result\191_Mo4Nb.cif
#  - result\192_Ir3V.cif
#  - result\193_Eu8Ge4.cif
#  - result\194_Al12Pb12.cif
#  - result\195_Ni6Ge18.cif
#  - result\196_Au8Mn4.cif
#  - result\197_Mn10Sn6.cif
#  - result\198_K8P4.cif
#  - result\199_Al2V.cif
#  - result\200_CsW.cif
#  - result\201_CrPd.cif
#  - result\202_K3Na.cif
#  - result\203_NaPb3.cif
#  - result\204_Ni3Sb.cif
#  - result\205_Ir3Mn4.cif
#  - result\206_Cr12W18.cif
#  - result\207_CrRh3.cif
#  - result\208_PI.cif
#  - result\209_CuI.cif
#  - result\210_Al18Pb6.cif
#  - result\211_WSb.cif
#  - result\212_Fe2Ga4.cif
#  - result\213_Mn2Sn2.cif
#  - result\214_PI.cif
#  - result\215_AgAl2.cif
#  - result\216_Cr5Rh4.cif
#  - result\217_Ge8Br.cif
#  - result\218_Ag5Al2.cif
#  - result\219_Ag4Al2.cif
#  - result\220_Cr8Rh.cif
#  - result\221_Mo7Nb.cif
#  - result\222_BaIr2.cif
#  - result\223_Pd12Ta18.cif
#  - result\224_K2As6.cif
#  - result\225_AlPd2.cif
#  - result\226_Al4Pb2.cif
#  - result\227_Ir2Na4.cif
#  - result\228_Ge3P.cif
#  - result\229_Pd2Rh2.cif
#  - result\230_Cu7Pt5.cif
#  - result\231_Ba3Ir.cif
#  - result\232_Ta3Ge.cif
#  - result\233_Ag6Al6.cif
#  - result\234_Ag5In.cif
#  - result\235_PAs3.cif
#  - result\236_VW2.cif
#  - result\237_Ba3Ir.cif
#  - result\238_In4Pb16.cif
#  - result\239_Pb2Sb6.cif
#  - result\240_PaBi.cif
#  - result\241_CrTa.cif
#  - result\242_Ag7Ta.cif
#  - result\243_FePb3.cif
#  - result\244_Ni4Rh2.cif
#  - result\245_AlRh2.cif
#  - result\246_WSb.cif
#  - result\247_Ba4Ir2.cif
#  - result\248_Cu5Pt7.cif
#  - result\249_Ni8Ta16.cif
#  - result\250_MoP3.cif
#  - result\251_Ba2Ni2.cif
#  - result\252_AuPt.cif
#  - result\253_Cu3Ge4.cif
#  - result\254_NbP2.cif
#  - result\255_Mo2Pb2.cif
#  - result\256_CuIr.cif
#  - result\257_AcMn.cif
#  - result\258_Cr5Nb.cif
#  - result\259_K2As2.cif
#  - result\260_CuNi.cif
#  - result\261_Fe3Na.cif
#  - result\262_BaBr3.cif
#  - result\263_Fe2Pb2.cif
#  - result\264_Cr4P.cif
#  - result\265_Pd16Ta14.cif
#  - result\266_Ag4Al4.cif
#  - result\267_CrP7.cif
#  - result\268_FeW2.cif
#  - result\269_SnP3.cif
#  - result\270_FeNa.cif
#  - result\271_PtV2.cif
#  - result\272_NbPb3.cif
#  - result\273_Ba3Br.cif
#  - result\274_CsBr.cif
#  - result\275_V4W4.cif
#  - result\276_K5Ge.cif
#  - result\277_Ba2Cu2.cif
#  - result\278_Al12Sn4.cif
#  - result\279_Ba2Cu4.cif
#  - result\280_K3P.cif
#  - result\281_YbBi.cif
#  - result\282_V2W.cif
#  - result\283_Fe3Pb.cif
#  - result\284_Cu6Pt6.cif
#  - result\285_MoPb3.cif
#  - result\286_Ca3P5.cif
#  - result\287_Ca12Mo4.cif
#  - result\288_As2Br6.cif
#  - result\289_P5As.cif
#  - result\290_W24P5.cif
#  - result\291_Fe24Pb5.cif
#  - result\292_Ga14Pt6.cif
#  - result\293_Mo4Pb2.cif
#  - result\294_RhU.cif
#  - result\295_Fe2Pb.cif
#  - result\296_Ag2Ge2.cif
#  - result\297_FePd3.cif
#  - result\298_PtV3.cif
#  - result\299_NbW3.cif
#  - result\300_Ag2Ca4.cif
#  - result\301_RhGe2.cif
#  - result\302_CuK.cif
#  - result\303_Sb3Ge.cif
#  - result\304_AlCu5.cif
#  - result\305_Au3Ga.cif
#  - result\306_Na2Pt2.cif
#  - result\307_NbW3.cif
#  - result\308_Na4Pb.cif
#  - result\309_Fe16Pd8.cif
#  - result\310_Ba6Sn2.cif
#  - result\311_Fe3Pd.cif
#  - result\312_Nb2W4.cif
#  - result\313_AgSn.cif
#  - result\314_Mo3Ta.cif
#  - result\315_CrNa.cif
#  - result\316_MnW.cif
#  - result\317_Fe4W2.cif
#  - result\318_Sb3Ge.cif
#  - result\319_GaNa3.cif
#  - result\320_AuGa3.cif
#  - result\321_PAs.cif
#  - result\322_Nb4V8.cif
#  - result\323_TaYb.cif
#  - result\324_BaGa4.cif
#  - result\325_Fe5Ir.cif
#  - result\326_Ba16Ir8.cif
#  - result\327_Au2Nb3.cif
#  - result\328_Ba2In.cif
#  - result\329_SnTa.cif
#  - result\330_FePd3.cif
#  - result\331_VW2.cif
#  - result\332_FePd2.cif
#  - result\333_K2P2.cif
#  - result\334_Ba2Cu.cif
#  - result\335_Cu3Sb.cif
#  - result\336_KP3.cif
#  - result\337_SmYb3.cif
#  - result\338_Nb2V.cif
#  - result\339_Na2Pt.cif
#  - result\340_Ag2Ge2.cif
#  - result\341_PtV3.cif
#  - result\342_Ag3Ge.cif
#  - result\343_TaGe3.cif
#  - result\344_Nb3W.cif
#  - result\345_Cu6Pt4.cif
#  - result\346_Ni4Rh8.cif
#  - result\347_SmTa.cif
#  - result\348_MnNb.cif
#  - result\349_Ga2As2.cif
#  - result\350_FeAs3.cif
#  - result\351_Cr3Rh.cif
#  - result\352_AuP3.cif
#  - result\353_Fe8Pd4.cif
#  - result\354_CaCr3.cif
#  - result\355_Cr3Sr.cif
#  - result\356_Ag3Ca.cif
#  - result\357_CeGa3.cif
#  - result\358_SbGe.cif
#  - result\359_As6Br2.cif
#  - result\360_Au3Cr.cif
#  - result\361_AlTa2.cif
#  - result\362_Au6Ga10.cif
#  - result\363_Nb8P.cif
#  - result\364_Ca2Sn.cif
#  - result\365_In2Na2.cif
#  - result\366_NiAs3.cif
#  - result\367_Al3Rh.cif
#  - result\368_CaW3.cif
#  - result\369_Ba3Sn.cif
#  - result\370_WAs2.cif
#  - result\371_Ag14Ca4.cif
#  - result\372_Ag4Al8.cif
#  - result\373_Mn8W16.cif
#  - result\374_Al6Rh6.cif
#  - result\375_Cu4Sn5.cif
#  - result\376_Mo3Sr.cif
#  - result\377_Au3Nb.cif
#  - result\378_CaW3.cif
#  - result\379_P3As.cif
#  - result\380_MoTa2.cif
#  - result\381_Sb4Ge2.cif
#  - result\382_AuNb2.cif
#  - result\383_Ni3Sm.cif
#  - result\384_CrAs3.cif
#  - result\385_IrPb2.cif
#  - result\386_Na2Pt2.cif
#  - result\387_FePd.cif
#  - result\388_IrBr3.cif
#  - result\389_Cr2As4.cif
#  - result\390_Pb6As2.cif
#  - result\391_Ga2Na.cif
#  - result\392_FePd3.cif
#  - result\393_Mn6W2.cif
#  - result\394_Cr7Nb.cif
#  - result\395_Ir2Pb2.cif
#  - result\396_Au2Nb2.cif
#  - result\397_AuNb3.cif
#  - result\398_Nb2V4.cif
#  - result\399_Au2Nb2.cif
#  - result\400_Ga3Na.cif
#  - result\401_AlGa3.cif
#  - result\402_GaNa3.cif
#  - result\403_Ag3Mn.cif
#  - result\404_Au3P.cif
#  - result\405_NaPt.cif
#  - result\406_As4Br.cif
#  - result\425_CsYb.cif
#  - result\443_Cr3Nb.cif
#  - result\444_Al2Pd.cif
#  - result\445_CrW3.cif
#  - result\452_AgAl2.cif
#  - result\461_Nb2Pt2.cif
#  - result\462_Fe2Pb4.cif
#  - result\463_Ni3Sb.cif
#  - result\470_P24As5.cif
#  - result\471_Mo3W3.cif
#  - result\472_Ca4P2.cif
#  - result\473_Ba4Br.cif
#  - result\474_KAs3.cif
#  - result\479_Ca18Mo6.cif
#  - result\480_Ag6Al6.cif
#  - result\481_RbW.cif
#  - result\482_MnMo3.cif
#  - result\483_Fe2Ga.cif
#  - result\484_Mn3Sn.cif
#  - result\485_PI.cif
#  - result\488_Ga2Sr.cif
#  - result\489_In2Br2.cif
#  - result\490_Cu5Ge.cif
#  - result\491_Ag2Al2.cif
#  - result\492_MoW3.cif
#  - result\493_Fe3Na.cif
#  - result\497_Al4Th6.cif
#  - result\498_Ge4Br5.cif
#  - result\499_Cu2Ga4.cif
#  - result\500_CuGe2.cif
#  - result\501_FeSb3.cif
#  - result\502_In5Sn.cif
#  - result\503_Sn2W.cif
#  - result\506_MnRh.cif
#  - result\507_Ba2Pd4.cif
#  - result\508_Ba3Sb.cif
#  - result\509_Pt3As.cif
#  - result\510_Ga2P.cif
#  - result\511_AgP.cif
#  - result\515_Ni4U6.cif
#  - result\516_Ba2Cu4.cif
#  - result\517_AlNi.cif
#  - result\518_CaPb5.cif
#  - result\519_Ag4Al.cif
#  - result\520_V2Br2.cif
#  - result\521_CuGe.cif
#  - result\522_FeTh.cif
#  - result\523_In2Sn.cif
#  - result\524_In2Sn4.cif
#  - result\525_MnBr8.cif
#  - result\526_GeP.cif
#  - result\527_Ca3Pb.cif
#  - result\528_IrTa3.cif
#  - result\529_AlPd3.cif
#  - result\530_AuNb.cif
#  - result\531_Pb3Ta.cif
#  - result\532_AlPd.cif
#  - result\533_Ga12P17.cif
#  - result\534_Ni2Sb2.cif
#  - result\535_MoTa2.cif
#  - result\536_KSn3.cif
#  - result\537_Fe2Ga2.cif
#  - result\538_As3Br.cif
#  - result\539_FePt3.cif
#  - result\540_V2Br.cif
#  - result\542_Fe12Mo17.cif
#  - result\543_Sr4Br8.cif
#  - result\544_Mn4Sb5.cif
#  - result\545_Ba2Pd4.cif
#  - result\546_As4Br.cif
#  - result\547_AgAl3.cif
#  - result\548_CuIr.cif
#  - result\549_FeNa.cif
#  - result\551_Ca12P12.cif
#  - result\552_Fe17Pb12.cif
#  - result\553_Al8Sn4.cif
#  - result\554_K8As.cif
#  - result\555_In2Sn4.cif
#  - result\556_Ir4Ta2.cif
#  - result\557_V2Br.cif
#  - result\558_K2Sn.cif
#  - result\560_Ir4As12.cif
#  - result\561_Ag4Al3.cif
#  - result\562_Mo2W4.cif
#  - result\563_CsNi.cif
#  - result\564_Ba2As4.cif
#  - result\565_BaBr2.cif
#  - result\566_NaPd3.cif
#  - result\567_K3Na.cif
#  - result\568_AsBr4.cif
#  - result\569_CuNi.cif
#  - result\570_Cr2Ta2.cif
#  - result\571_Ba2V.cif
#  - result\572_Ni2Sn2.cif
#  - result\573_Fe3Ga.cif
#  - result\574_Ag2Al.cif
#  - result\575_AcRb.cif
#  - result\576_CrNa.cif
#  - result\577_Ba3Ir.cif
#  - result\578_Cu5Ge4.cif
#  - result\579_K4As2.cif
#  - result\580_SmBi.cif
#  - result\581_BaPd3.cif
#  - result\582_InBr3.cif
#  - result\583_InBr5.cif
#  - result\584_Ba3Fe.cif
#  - result\585_AuNi.cif
#  - result\586_AuSr.cif
#  - result\587_Ac4Br6.cif
#  - result\588_Ag4Al4.cif
#  - result\589_Ni2P6.cif
#  - result\590_Sb4Ge2.cif
#  - result\591_AlPd.cif
#  - result\592_InSb.cif
#  - result\593_Ba2Br4.cif
#  - result\594_AlP2.cif
#  - result\595_Fe2Ga2.cif
#  - result\596_Cr6Ta18.cif
#  - result\597_Cu6Pt5.cif
#  - result\598_K2Ge2.cif
#  - result\599_Ag2Na.cif
#  - result\600_Ni4Ta4.cif
#  - result\601_VGe3.cif
#  - result\602_W2As2.cif
#  - result\603_CrP7.cif
#  - result\604_Cu4Ni2.cif
#  - result\605_Fe4Mo16.cif
#  - result\606_Ni3Np.cif
#  - result\607_NaI.cif
#  - result\608_Au2P.cif
#  - result\609_GaP2.cif
#  - result\610_CuNi4.cif
#  - result\611_BaTa3.cif
#  - result\612_NiTa2.cif
#  - result\613_IrAs.cif
#  - result\614_Ge18P6.cif
#  - result\615_Au12Sr17.cif
#  - result\616_Mo2Nb2.cif
#  - result\617_PaGe3.cif
#  - result\618_TaGe4.cif
#  - result\619_Pd2Rh2.cif
#  - result\620_K2As2.cif
#  - result\621_V3Br.cif
#  - result\622_Fe2Pb2.cif
#  - result\623_K2As2.cif
#  - result\624_Fe5As3.cif
#  - result\625_AsBr3.cif
#  - result\626_AgAl2.cif
#  - result\627_AuIr.cif
#  - result\628_FeIr2.cif
#  - result\629_AlP.cif
#  - result\630_P4As.cif
#  - result\631_SrW.cif
#  - result\632_Nb4I16.cif
#  - result\633_Fe4V12.cif
#  - result\634_Al2Th4.cif
#  - result\635_CrNb.cif
#  - result\636_Pd3Sb.cif
#  - result\637_KAs2.cif
#  - result\638_Ta2V2.cif
#  - result\639_Ni2P2.cif
#  - result\640_SrW.cif
#  - result\641_Al6Rh6.cif
#  - result\642_As4Br16.cif
#  - result\643_Al4Pb8.cif
#  - result\644_Al2Pt2.cif
#  - result\645_CaBr3.cif
#  - result\646_Al3Sb.cif
#  - result\647_PtTh.cif
#  - result\648_CrTa.cif
#  - result\649_AuPa.cif
#  - result\650_Mo5P24.cif
#  - result\651_Mo4P8.cif
#  - result\652_AlP4.cif
#  - result\653_NaP.cif
#  - result\654_Al2In4.cif
#  - result\655_PdRh2.cif
#  - result\656_CrSb.cif
#  - result\657_CsI.cif
#  - result\658_AgAl5.cif
#  - result\659_Ce4Fe34.cif
#  - result\660_Al3Ca.cif
#  - result\661_CrTh.cif
#  - result\662_AgAl2.cif
#  - result\663_Ni2Sn.cif
#  - result\664_Al3Pd.cif
#  - result\665_AsBr4.cif
#  - result\666_Ag3Ta.cif
#  - result\667_MoP3.cif
#  - result\668_MoSn.cif
#  - result\669_Cr8Nb.cif
#  - result\670_Nb2P4.cif
#  - result\671_NpPd.cif
#  - result\672_Ba2Ta4.cif
#  - result\673_Fe3Ga.cif
#  - result\674_Fe2Ir.cif
#  - result\675_AlRh3.cif
#  - result\676_AgTa3.cif
#  - result\677_W6As10.cif
#  - result\678_Na4Pt8.cif
#  - result\679_GaMn2.cif
#  - result\680_EuGa3.cif
#  - result\681_Pt3V.cif
#  - result\682_Fe2Ga2.cif
#  - result\683_Cr3Na.cif
#  - result\684_AgAs.cif
#  - result\685_Pt2Sn2.cif
#  - result\686_Cu4Ge2.cif
#  - result\687_In3Ni.cif
#  - result\688_AuV.cif
#  - result\689_In3Sr.cif
#  - result\690_Ag6Al2.cif
#  - result\691_AgNi2.cif
#  - result\692_Fe2Mo.cif
#  - result\693_Mo7P.cif
#  - result\694_AsBr3.cif
#  - result\695_In4Br2.cif
#  - result\696_Ag3Ge.cif
#  - result\697_Ge2P6.cif
#  - result\698_TaGe2.cif
#  - result\699_NbW3.cif
#  - result\700_BaV2.cif
#  - result\701_Fe2W4.cif
#  - result\702_Al2K2.cif
#  - result\703_Pb5As.cif
#  - result\704_Cu7Pt5.cif
#  - result\705_P16As8.cif
#  - result\706_Ta4V6.cif
#  - result\707_Pd3Sb.cif
#  - result\708_Fe4Pd8.cif
#  - result\709_CeTa.cif
#  - result\710_K2Ge2.cif
#  - result\711_CrNb.cif
#  - result\712_PtSb3.cif
#  - result\713_Ir18Ta6.cif
#  - result\714_Fe2Pd26.cif
#  - result\715_Mo2Sr2.cif
#  - result\716_CuNb.cif
#  - result\717_TaBi.cif
#  - result\718_AgGe5.cif
#  - result\719_BaV3.cif
#  - result\720_GaPt4.cif
#  - result\721_AgMn3.cif
#  - result\722_Al14Th4.cif
#  - result\723_Mo2Sr4.cif
#  - result\724_Mo2W6.cif
#  - result\725_SrV.cif
#  - result\726_Ca2Pb6.cif
#  - result\727_Ga2W.cif
#  - result\728_FeBr3.cif
#  - result\729_CrNb.cif
#  - result\730_Ni3Ta.cif
#  - result\731_Cr6Pb18.cif
#  - result\732_AgSn2.cif
#  - result\733_Pt2Sb.cif
#  - result\734_Fe3Ir4.cif
#  - result\735_CrSr3.cif
#  - result\736_Cr2Nb4.cif
#  - result\737_NiBi3.cif
#  - result\738_BaV2.cif
#  - result\739_Ag2Ta4.cif
#  - result\740_Ag5Al7.cif
#  - result\741_Cr6Ge2.cif
#  - result\742_SnW2.cif
#  - result\743_Al4P2.cif
#  - result\744_V4W3.cif
#  - result\745_CaCr3.cif
#  - result\746_GaAs2.cif
#  - result\747_Mo3Ta.cif
#  - result\748_Mo2P.cif
#  - result\749_Mo10W6.cif
#  - result\750_Cr2As4.cif
#  - result\751_Ca3Ir.cif
#  - result\752_Ba2Ga2.cif
#  - result\753_Ir2V4.cif
#  - result\754_Ba3Sn.cif
#  - result\755_RhV.cif
#  - result\756_Fe2Ir2.cif
#  - result\757_W5P.cif
#  - result\758_Cu4Pt7.cif
#  - result\759_P4Br16.cif
#  - result\760_Cr26Nb2.cif
#  - result\761_CuMo.cif
#  - result\762_Na2Pt4.cif
#  - result\763_PbAs3.cif
#  - result\764_Al2K2.cif
#  - result\765_K2As2.cif
#  - result\766_Au3Ga.cif
#  - result\767_Al18Pt6.cif
#  - result\768_Mo8Nb16.cif
#  - result\769_P16Br4.cif
#  - result\770_Cr4Sr5.cif
#  - result\771_Al2Pt4.cif
#  - result\772_PbGe3.cif
#  - result\773_InTa3.cif
#  - result\774_W5Sb.cif
#  - result\775_MoI.cif
#  - result\776_As17Br12.cif
#  - result\777_Al2Cu6.cif
#  - result\778_NaPb.cif
#  - result\779_As4Br2.cif
#  - result\780_NiTa.cif
#  - result\781_Ir2V.cif
#  - result\782_FeIr2.cif
#  - result\783_Fe2Ir2.cif
#  - result\784_AuCr3.cif
#  - result\785_Mn4W16.cif
#  - result\786_Al8Ta4.cif
#  - result\787_Al3I.cif
#  - result\788_CrTa3.cif
#  - result\789_AuP3.cif
#  - result\790_Ba5V.cif
#  - result\791_K2As.cif
#  - result\792_AuNp.cif
#  - result\793_PdRh2.cif
#  - result\794_Sb5Ge.cif
#  - result\795_MoSr2.cif
#  - result\796_RhBi.cif
#  - result\797_Al2K4.cif
#  - result\798_Ba2Sn4.cif
#  - result\799_Ba3In.cif
#  - result\800_Fe3Pd.cif
#  - result\801_Ag2Sn.cif
#  - result\802_FePd.cif
#  - result\803_Au5Sr24.cif
#  - result\804_Au16Sr4.cif
#  - result\805_Ca2Cu2.cif
#  - result\806_Al2Cu2.cif
#  - result\807_Mo2Ta.cif
#  - result\808_In5Ta3.cif
#  - result\809_PbAs3.cif
#  - result\810_Cu3K.cif
#  - result\811_NaPt.cif
#  - result\812_V4W2.cif
#  - result\813_Cr4As.cif
#  - result\814_Ag8Mn.cif
#  - result\815_Pd4Rh.cif
#  - result\816_Al3In.cif
#  - result\817_SmI3.cif
#  - result\818_Ga3W.cif
#  - result\819_Au3Nb.cif
#  - result\820_AgSn2.cif
#  - result\821_Ag12Br4.cif
#  - result\822_Ca5Sn7.cif
#  - result\823_Nb2V.cif
#  - result\824_Nb2W.cif
#  - result\825_IrV5.cif
#  - result\826_BaSn5.cif
#  - result\827_Nb3V.cif
#  - result\828_PAs.cif
#  - result\829_Fe3Pb.cif
#  - result\830_Mn4W16.cif
#  - result\831_Ag4Ge12.cif
#  - result\832_Ni6P2.cif
#  - result\833_Sb3Ge.cif
#  - result\834_Ag5Sn3.cif
#  - result\835_Ag3Br.cif
#  - result\836_MnW5.cif
#  - result\837_Mn2W2.cif
#  - result\838_PAs.cif
#  - result\839_Pb4As4.cif
#  - result\840_Cu2Ge.cif
#  - result\841_Pb2As6.cif
#  - result\842_Na4Pt2.cif
#  - result\843_SbGe3.cif
#  - result\844_Au2Nb4.cif
#  - result\845_Ni3Sb.cif
#  - result\846_In2Ta2.cif
#  - result\847_Fe3Pb.cif
#  - result\920_Cr24P5.cif
#  - result\921_Cr4P8.cif
#  - result\922_Ag4Al4.cif
#  - result\923_Ca4P6.cif
#  - result\924_Fe16Na4.cif
#  - result\925_In5Sn.cif
#  - result\926_Nb4Pb4.cif
#  - result\927_Pb2Sb2.cif
#  - result\928_CaMo3.cif
#  - result\929_GeP3.cif
#  - result\930_Ba4Pd2.cif
#  - result\931_Pt2As.cif
#  - result\932_BaBr2.cif
#  - result\933_BiP.cif
#  - result\934_Nb2Pb4.cif
#  - result\935_BaPd5.cif
#  - result\936_FeAs3.cif
#  - result\937_V4Br2.cif
#  - result\938_Ca4In.cif
#  - result\939_In2Sn2.cif
#  - result\940_BiGe.cif
#  - result\941_FeIn.cif
#  - result\942_Cu2Ga2.cif
#  - result\943_USb.cif
#  - result\944_Sb5Ge.cif
#  - result\945_RbRh.cif
#  - result\946_Al10Ga6.cif
#  - result\947_Au12Nb12.cif
#  - result\948_Al4Ce.cif
#  - result\949_Cr12Ta12.cif
#  - result\950_Sb3Ge.cif
#  - result\951_Fe2Mo.cif
#  - result\952_Pb2As4.cif
#  - result\953_Al2In6.cif
#  - result\954_Ga24Pt5.cif
#  - result\955_V3Br.cif
#  - result\956_GaU.cif
#  - result\957_BaBr3.cif
#  - result\958_Al3In.cif
#  - result\959_GaAs2.cif
#  - result\960_In2Br4.cif
#  - result\961_PaSr.cif
#  - result\962_In2Na.cif
#  - result\963_Pb5As.cif
#  - result\964_KMn.cif
#  - result\965_Cr3Sr.cif
#  - result\966_Ag2Ca.cif
#  - result\967_Ga2K.cif
#  - result\968_IrV3.cif
#  - result\969_CsW.cif
#  - result\970_Nb4W8.cif
#  - result\971_Cr6Ta2.cif
#  - result\972_NiP4.cif
#  - result\973_MnW.cif
#  - result\974_AgMn8.cif
#  - result\975_GaW4.cif
#  - result\976_InNa3.cif
#  - result\977_SmW.cif
#  - result\978_AlIn3.cif
#  - result\979_AuNb3.cif
#  - result\980_CrTa.cif
#  - result\981_AlMo3.cif
#  - result\982_Cr2Na2.cif
#  - result\983_Ag2Sn.cif
#  - result\984_IrV3.cif
#  - result\985_BaIr3.cif
#  - result\986_PAs.cif
#  - result\987_Cr2Na2.cif
#  - result\988_W3As.cif
#  - result\989_Cr5Sr4.cif
#  - result\990_Ga16Pt4.cif
#  - result\991_Ni4Rh2.cif
#  - result\992_K3Na.cif
#  - result\993_Ba4Ni6.cif
#  - result\994_Ga3Pt5.cif
#  - result\995_Cu2Ge4.cif
#  - result\996_AuCr2.cif
#  - result\997_Ga3W.cif
#  - result\998_KI.cif
#  - result\999_K3Na.cif
#  - result\1000_Fe2Ga4.cif
#  - result\1001_Ge2Br.cif
#  - result\1002_RhV.cif
#  - result\1003_InSb.cif
#  - result\1004_Ag2Al.cif
#  - result\1005_Cu2Ge2.cif
#  - result\1006_Cu2Ge.cif
#  - result\1007_CrRh4.cif
#  - result\1008_NpU.cif
#  - result\1009_RhU.cif
#  - result\1010_Cr3W.cif
#  - result\1011_Cr2Rh2.cif
#  - result\1012_KPt.cif
#  - result\1013_Ge2Br2.cif
#  - result\1014_CrRh2.cif
#  - result\1015_Cr8Rh.cif
#  - result\1016_FePt.cif
#  - result\1017_CuGa.cif
#  - result\1018_AlPd3.cif
#  - result\1019_Cr5Rh4.cif
#  - result\1020_MoV4.cif
#  - result\1021_Ni3Sb.cif
#  - result\1022_SmGe5.cif
#  - result\1023_Ac4I6.cif
#  - result\1024_Fe4Ga2.cif
#  - result\1025_KPb2.cif
#  - result\1026_Ge2P4.cif
#  - result\1027_CaFe.cif
#  - result\1028_FeP.cif
#  - result\1029_AlNb3.cif
#  - result\1030_CrNb2.cif
#  - result\1031_BaFe2.cif
#  - result\1032_Fe2Ga.cif
#  - result\1033_Ir2Mn2.cif
#  - result\1034_Cr3W.cif
#  - result\1035_K2Sn.cif
#  - result\1036_Au16Sr4.cif
#  - result\1037_AlCa3.cif
#  - result\1038_Ag6Al4.cif
#  - result\1039_Nb2P2.cif
#  - result\1040_Cu8Pt4.cif
#  - result\1041_Fe5Ir4.cif
#  - result\1042_Fe4Pb.cif
#  - result\1043_AsBr2.cif
#  - result\1044_Fe2Mo4.cif
#  - result\1045_VGe3.cif
#  - result\1046_Mo2W.cif
#  - result\1047_K2Na4.cif
#  - result\1048_Cu7Pt5.cif
#  - result\1049_Fe4V2.cif
#  - result\1050_Pd8Sb4.cif
#  - result\1051_W4Sb16.cif
#  - result\1052_CuIr.cif
#  - result\1053_Cr2Ta6.cif
#  - result\1054_Sr16W4.cif
#  - result\1055_SrW3.cif
#  - result\1056_NiSn.cif
#  - result\1057_Fe4V12.cif
#  - result\1058_V4W2.cif
#  - result\1059_Ir18Mo6.cif
#  - result\1060_CuTh.cif
#  - result\1061_AgNa2.cif
#  - result\1062_MoP.cif
#  - result\1063_Pb8Sb4.cif
#  - result\1064_EuU.cif
#  - result\1065_Cr3Rh.cif
#  - result\1066_Ag2Na4.cif
#  - result\1067_CuGe.cif
#  - result\1068_Ca3Ni.cif
#  - result\1069_As2Br.cif
#  - result\1070_Ni5Ta.cif
#  - result\1071_AsBr2.cif
#  - result\1072_Fe2Pb2.cif
#  - result\1073_SrW3.cif
#  - result\1074_NiSn2.cif
#  - result\1075_Sr2W2.cif
#  - result\1076_Ir3K.cif
#  - result\1077_AgTa7.cif
#  - result\1078_Pt24Ge16.cif
#  - result\1079_AuGa.cif
#  - result\1080_AsBr2.cif
#  - result\1081_Fe3Na.cif
#  - result\1082_Pb4V.cif
#  - result\1083_Ba3Ta.cif
#  - result\1084_Fe3Pb.cif
#  - result\1085_Fe4As6.cif
#  - result\1086_Al2Rh.cif
#  - result\1087_Fe2Pb2.cif
#  - result\1088_NaPt4.cif
#  - result\1089_MoP.cif
#  - result\1090_Al3K.cif
#  - result\1091_W2Sb6.cif
#  - result\1092_AsBr.cif
#  - result\1093_BaTa3.cif
#  - result\1094_NaPt.cif
#  - result\1095_Cr4Ta6.cif
#  - result\1096_Ga2W6.cif
#  - result\1097_Pb2Sb2.cif
#  - result\1098_Pt2Sn2.cif
#  - result\1099_AuU.cif
#  - result\1100_WSb.cif
#  - result\1101_MoI.cif
#  - result\1102_MoSr2.cif
#  - result\1103_NbP3.cif
#  - result\1104_PdRh4.cif
#  - result\1105_Al4In2.cif
#  - result\1106_SnW.cif
#  - result\1107_Pb3V.cif
#  - result\1108_WSb4.cif
#  - result\1109_As3Br.cif
#  - result\1110_Ag6V10.cif
#  - result\1111_Ag7Al5.cif
#  - result\1112_Cr3Ta.cif
#  - result\1113_IrAs5.cif
#  - result\1114_Pb2V.cif
#  - result\1115_Ba4Ni6.cif
#  - result\1116_Ir2Ta4.cif
#  - result\1117_Al8Pb4.cif
#  - result\1118_Ag4Al3.cif
#  - result\1119_AlPd2.cif
#  - result\1120_Al6Pb18.cif
#  - result\1121_Cr4Rh8.cif
#  - result\1122_Au4Mn6.cif
#  - result\1123_Au8Mn4.cif
#  - result\1124_Ge4Br2.cif
#  - result\1125_AlMo2.cif
#  - result\1126_Mn4Sn.cif
#  - result\1127_AgAl4.cif
#  - result\1128_Ni5Sb4.cif
#  - result\1129_Al2Pb4.cif
#  - result\1130_Ir4Mn3.cif
#  - result\1131_Cu8Ge.cif
#  - result\1132_FePt3.cif
#  - result\1133_Mn2Sn4.cif
#  - result\1134_Fe2Pb6.cif
#  - result\1135_BaIr2.cif
#  - result\1136_Mo4Pb8.cif
#  - result\1137_Al4Pb8.cif
#  - result\1138_Au2Mn6.cif
#  - result\1139_AuIn8.cif
#  - result\1140_CrRh8.cif
#  - result\1141_AlPd2.cif
#  - result\1142_InTa3.cif
#  - result\1143_Au2As2.cif
#  - result\1144_Ce3Sn.cif
#  - result\1145_Ba2Ir4.cif
#  - result\1146_Fe8Pb4.cif
#  - result\1147_K2P2.cif
#  - result\1148_As4Br.cif
#  - result\1149_NbI.cif
#  - result\1150_GaPt3.cif
#  - result\1151_NbBi3.cif
#  - result\1152_K2P2.cif
#  - result\1153_AuCu3.cif
#  - result\1154_BaIr3.cif
#  - result\1155_Ca3Pb.cif
#  - result\1156_Fe44Mo2.cif
#  - result\1157_Cr4Nb2.cif
#  - result\1158_NaPd2.cif
#  - result\1159_SnW3.cif
#  - result\1160_Fe3As.cif
#  - result\1161_AuMo.cif
#  - result\1162_Fe6V4.cif
#  - result\1163_Mo3W.cif
#  - result\1164_Ba4Cu2.cif
#  - result\1165_Nb10Ge6.cif
#  - result\1166_As3Br.cif
#  - result\1167_AgTa3.cif
#  - result\1168_Pb5Sr24.cif
#  - result\1169_Cu6Pt5.cif
#  - result\1170_NbP3.cif
#  - result\1171_Mo2P6.cif
#  - result\1172_CuNi.cif
#  - result\1173_GaP4.cif
#  - result\1174_PbV4.cif
#  - result\1175_Ba5Pd.cif
#  - result\1176_Mo2W2.cif
#  - result\1177_PAs5.cif
#  - result\1178_P12As17.cif
#  - result\1179_As4Br2.cif
#  - result\1180_Mo3W.cif
#  - result\1181_MoPb5.cif
#  - result\1182_Nb2Pb4.cif
#  - result\1183_K3Sn.cif
#  - result\1184_Ca3Pb.cif
#  - result\1185_AsBr.cif
#  - result\1186_Ag6Al2.cif
#  - result\1187_AsBr8.cif
#  - result\1188_Ca6P2.cif
#  - result\1189_CuBr3.cif
#  - result\1190_Pd2Sb4.cif
#  - result\1191_CrNb.cif
#  - result\1192_Ge8I32.cif
#  - result\1193_Ag7Al3.cif
#  - result\1194_MnSb8.cif
#  - result\1195_Ag5Al3.cif
#  - result\1196_Ba4Sb2.cif
#  - result\1197_KGe3.cif
#  - result\1198_Ag5Al3.cif
#  - result\1199_Pt10Sn6.cif
#  - result\1200_K4Ni2.cif
#  - result\1201_Cu6Pt4.cif
#  - result\1202_PdTa4.cif
#  - result\1203_BaCu5.cif
#  - result\1204_PdW2.cif
#  - result\1205_PAs3.cif
#  - result\1206_K2Ge6.cif
#  - result\1207_Ce4Ge4.cif
#  - result\1208_W16Sb4.cif
#  - result\1209_Ag4Al.cif
#  - result\1210_In2Ge2.cif
#  - result\1211_PbSb.cif
#  - result\1212_Ir4Ta2.cif
#  - result\1213_Al9Sr5.cif
#  - result\1214_GaW3.cif
#  - result\1215_Ag3Mn.cif
#  - result\1216_Pb16Sr4.cif
#  - result\1217_Pt4Sr2.cif
#  - result\1218_Ba4Cu8.cif
#  - result\1219_Pd2Ta2.cif
#  - result\1220_Ba4As.cif
#  - result\1221_Mo3Pb.cif
#  - result\1222_K5Ge.cif
#  - result\1223_Al2Cu.cif
#  - result\1224_Na3Pt.cif
#  - result\1225_FePd3.cif
#  - result\1226_Ag4Al.cif
#  - result\1227_Mn2W6.cif
#  - result\1228_Mn2V2.cif
#  - result\1229_Nb2V6.cif
#  - result\1230_Mo5W.cif
#  - result\1231_AgMn4.cif
#  - result\1232_Pt7Sb.cif
#  - result\1233_Ba2Ga2.cif
#  - result\1234_SbGe3.cif
#  - result\1235_FePb.cif
#  - result\1236_Ag2Ge4.cif
#  - result\1237_CaNi5.cif
#  - result\1238_Cr2Ta2.cif
#  - result\1239_Ba2Sn2.cif
#  - result\1240_VW3.cif
#  - result\1241_VW2.cif
#  - result\1242_CrAs3.cif
#  - result\1243_Ag2Ge6.cif
#  - result\1244_V10W6.cif
#  - result\1245_P17Br12.cif
#  - result\1246_Al3Cu5.cif
#  - result\1247_Ba2Ga2.cif
#  - result\1248_Pd2Sn2.cif
#  - result\1249_AuNb3.cif
#  - result\1250_Ag2Mn.cif
#  - result\1251_Ba3Ir.cif
#  - result\1252_Cr16Nb4.cif
#  - result\1253_AgBr3.cif
#  - result\1254_P8Br16.cif
#  - result\1255_Ga4W.cif
#  - result\1256_Ag2Ge2.cif
#  - result\1257_Ba6Ir2.cif
#  - result\1258_AgBr3.cif
#  - result\1259_VW3.cif
#  - result\1260_KP3.cif
#  - result\1261_FePb3.cif
#  - result\1262_Cr6Ta18.cif
#  - result\1263_Ni2P4.cif
#  - result\1264_Sb4Ge2.cif
#  - result\1265_CsNi.cif
#  - result\1266_Mn5Sb.cif
#  - result\1267_Al2Rh2.cif
#  - result\1268_Ca3W.cif
#  - result\1269_PdSn3.cif
#  - result\1270_Cu2Sn2.cif
#  - result\1271_GaMn3.cif
#  - result\1272_Ba6Ga2.cif
#  - result\1273_Ag2Mn4.cif
#  - result\1274_Al5Sr.cif
#  - result\1275_Ca2W2.cif
#  - result\1276_Mn3W.cif
#  - result\1277_PtSb3.cif
#  - result\1278_CrNb3.cif
#  - result\1279_MnW3.cif
#  - result\1280_Fe17Pd12.cif
#  - result\1281_Mn8W16.cif
#  - result\1282_Ga8Pt16.cif
#  - result\1283_CaNi5.cif
#  - result\1284_Cr4Nb4.cif
#  - result\1285_Ga4As2.cif
#  - result\1286_Ta2V4.cif
#  - result\1287_Nb3Sn.cif
#  - result\1288_FeIr3.cif
#  - result\1289_Bi16I4.cif
#  - result\1290_Ag2Br2.cif
#  - result\1291_Al5Sb.cif
#  - result\1292_CrNb2.cif
#  - result\1293_Au3Ir.cif
#  - result\1294_Au3Ga.cif
#  - result\1295_Pt3Sb.cif
#  - result\1296_Cr7Nb.cif
#  - result\1297_RhU.cif
#  - result\1298_Al12K12.cif
#  - result\1299_Cr2Na6.cif
#  - result\1300_Al4P2.cif
#  - result\1301_Al2Sb4.cif
#  - result\1302_Ir2Pb4.cif
#  - result\1303_Ga4W.cif
#  - result\1304_SrAs3.cif
#  - result\1305_GaW2.cif
#  - result\1306_Na6Pb2.cif
#  - result\1307_Fe26Pd2.cif
#  - result\1308_Ba2Sn4.cif
#  - result\1309_Al2Cu.cif
#  - result\1310_Ag4Mn2.cif
#  - result\1311_FeW.cif
#  - result\1312_PtSb3.cif
#  - result\1313_Sn4W.cif
#  - result\1314_Ta3V.cif
#  - result\1315_P7As.cif
#  - result\1316_TaGe3.cif
#  - result\1352_Fe4Pt8.cif
#  - result\1353_Ni2Sb4.cif
#  - result\1354_V3Br.cif
#  - result\1361_Pt2Sb2.cif
#  - result\1362_CuPb.cif
#  - result\1363_BaFe2.cif
#  - result\1364_Ca2In2.cif
#  - result\1365_FePb3.cif
#  - result\1370_Cr5Nb24.cif
#  - result\1379_Cu18As6.cif
#  - result\1380_Fe4Pb8.cif
#  - result\1381_Mo4Pb4.cif
#  - result\1382_In2Mn4.cif
#  - result\1383_CrPt3.cif
#  - result\1384_VBr3.cif
#  - result\1388_Fe8Na16.cif
#  - result\1389_Cu2Ga4.cif
#  - result\1390_Ga2Pt4.cif
#  - result\1391_PdTa2.cif
#  - result\1392_GaNb.cif
#  - result\1397_Cr20W10.cif
#  - result\1398_Ga2Nb6.cif
#  - result\1399_Ni2Sb.cif
#  - result\1400_VBr2.cif
#  - result\1401_Ir2Na2.cif
#  - result\1402_PaSn.cif
#  - result\1403_Ba3Br.cif
#  - result\1404_Al3Pd.cif
#  - result\1406_Cu2Br2.cif
#  - result\1407_BaAs.cif
#  - result\1408_Au4As2.cif
#  - result\1409_Cu5Br.cif
#  - result\1410_K2Na.cif
#  - result\1411_Mo2W4.cif
#  - result\1412_FeK.cif
#  - result\1413_Nb2Pb2.cif
#  - result\1415_Mo4Pb4.cif
#  - result\1416_Cu2Ge6.cif
#  - result\1417_Mn2Sb.cif
#  - result\1418_Ag4Al2.cif
#  - result\1419_Fe2Pb4.cif
#  - result\1420_CaCs.cif
#  - result\1421_In2Ta.cif
#  - result\1422_Ba2Br.cif
#  - result\1423_SnW3.cif
#  - result\1424_Pd12Sb4.cif
#  - result\1425_Mn6Sb2.cif
#  - result\1426_In4Sn2.cif
#  - result\1427_Ni3Sb.cif
#  - result\1428_InV.cif
#  - result\1429_Ga3Br.cif
#  - result\1430_BaCu.cif
#  - result\1431_Ba2Br.cif
#  - result\1432_Pb2Ta2.cif
#  - result\1433_Cr16W14.cif
#  - result\1434_Cr12P17.cif
#  - result\1435_Ni4Sb2.cif
#  - result\1436_AlFe.cif
#  - result\1437_GaP.cif
#  - result\1438_KNa3.cif
#  - result\1439_PbTa3.cif
#  - result\1440_KI.cif
#  - result\1441_BaCu3.cif
#  - result\1442_Ag8P16.cif
#  - result\1443_Pd4Ge2.cif
#  - result\1444_Au5Nb3.cif
#  - result\1445_CsI.cif
#  - result\1446_GaNb.cif
#  - result\1447_Fe2Pb2.cif
#  - result\1448_PtV3.cif
#  - result\1449_Fe4Na.cif
#  - result\1450_Pb4V.cif
#  - result\1451_PbI2.cif
#  - result\1452_In3Br3.cif
#  - result\1453_Na3Pd.cif
#  - result\1454_Al2Sn6.cif
#  - result\1455_SrBi.cif
#  - result\1456_Ir4Na2.cif
#  - result\1457_Au2Nb4.cif
#  - result\1458_CsYb.cif
#  - result\1459_CsW.cif
#  - result\1460_Ge8I32.cif
#  - result\1461_Pd2Ge4.cif
#  - result\1462_P4Br8.cif
#  - result\1463_Cr2Na.cif
#  - result\1464_Ir2Mo.cif
#  - result\1465_BaAs.cif
#  - result\1466_Fe6Na2.cif
#  - result\1467_GaPt4.cif
#  - result\1468_Cr3P.cif
#  - result\1469_CuGe.cif
#  - result\1470_Ir2Na2.cif
#  - result\1471_CuGe.cif
#  - result\1472_SnW4.cif
#  - result\1473_VBr2.cif
#  - result\1474_Ge2Br2.cif
#  - result\1475_Ca2P2.cif
#  - result\1476_Ni3Ta.cif
#  - result\1477_CuFe.cif
#  - result\1478_Ta2Ge6.cif
#  - result\1479_Fe6Sb2.cif
#  - result\1480_Fe2Pb2.cif
#  - result\1481_Fe3V.cif
#  - result\1482_Cr8P4.cif
#  - result\1483_Fe2Pb4.cif
#  - result\1484_Nb2P.cif
#  - result\1485_BaCu5.cif
#  - result\1486_InIr.cif
#  - result\1487_Fe8W4.cif
#  - result\1488_IrTa.cif
#  - result\1489_Ge2P2.cif
#  - result\1490_PbSb3.cif
#  - result\1491_AsBr5.cif
#  - result\1492_K6Sn2.cif
#  - result\1493_InK2.cif
#  - result\1494_Fe7Pb.cif
#  - result\1495_UI.cif
#  - result\1496_Cu12Ni17.cif
#  - result\1497_W5Sb24.cif
#  - result\1498_CuTh.cif
#  - result\1499_Fe6Sb2.cif
#  - result\1500_Ag2Al4.cif
#  - result\1501_Au2Nb2.cif
#  - result\1502_Fe5Mo.cif
#  - result\1503_FeMo5.cif
#  - result\1504_FeNa3.cif
#  - result\1505_Ce4Cu4.cif
#  - result\1506_Ba2Pd2.cif
#  - result\1507_Ge2As4.cif
#  - result\1508_Na2Pd2.cif
#  - result\1509_Fe4Na8.cif
#  - result\1510_CrNb4.cif
#  - result\1511_V2W.cif
#  - result\1512_CuNi.cif
#  - result\1513_CrP3.cif
#  - result\1514_Ga16Pt8.cif
#  - result\1515_Fe16Na4.cif
#  - result\1516_Ge2P4.cif
#  - result\1517_Na4Pt4.cif
#  - result\1518_Mo2Pb4.cif
#  - result\1519_Cr2Ta4.cif
#  - result\1520_NpYb.cif
#  - result\1521_InBr5.cif
#  - result\1522_Cu6Ni2.cif
#  - result\1523_Ga2Br6.cif
#  - result\1524_KAs8.cif
#  - result\1525_CsYb.cif
#  - result\1526_CrTh.cif
#  - result\1527_Ba2Br2.cif
#  - result\1528_RhU.cif
#  - result\1529_AgCa2.cif
#  - result\1530_NiTa5.cif
#  - result\1531_AuCu3.cif
#  - result\1532_Nb10P6.cif
#  - result\1533_Ga5P24.cif
#  - result\1534_Cu8Sn.cif
#  - result\1535_Ba2Pd.cif
#  - result\1536_Ta5V.cif
#  - result\1537_BaV2.cif
#  - result\1538_MoNb.cif
#  - result\1539_Ir3As.cif
#  - result\1540_Ag3P.cif
#  - result\1541_Pd8Ta22.cif
#  - result\1542_BaAs8.cif
#  - result\1543_Cu5Pb4.cif
#  - result\1544_Mn2Sb2.cif
#  - result\1545_Ca4In.cif
#  - result\1546_Mo2Pb4.cif
#  - result\1547_GaAs2.cif
#  - result\1548_Ni2Br6.cif
#  - result\1549_Ga3P.cif
#  - result\1550_Ag4Al6.cif
#  - result\1551_Cr16Nb4.cif
#  - result\1552_Pd4Sn4.cif
#  - result\1553_AlTa2.cif
#  - result\1554_Ba5P.cif
#  - result\1555_FeW.cif
#  - result\1556_Fe6Mo2.cif
#  - result\1557_CuGe3.cif
#  - result\1558_AuPb.cif
#  - result\1559_Cu6Pt5.cif
#  - result\1560_SmSr.cif
#  - result\1561_CrMn.cif
#  - result\1562_NiP.cif
#  - result\1563_Ag2Na4.cif
#  - result\1564_Fe4W2.cif
#  - result\1565_In2Br2.cif
#  - result\1566_NbP2.cif
#  - result\1567_AgIn3.cif
#  - result\1568_Cs16Bi16.cif
#  - result\1569_Pd20Ta10.cif
#  - result\1570_Ge4As2.cif
#  - result\1571_Ca2Rh4.cif
#  - result\1572_Ba2Ta2.cif
#  - result\1573_Al2Nb2.cif
#  - result\1574_Al4Sn2.cif
#  - result\1575_AuP3.cif
#  - result\1576_Ag2Sn.cif
#  - result\1577_Cr4Sn8.cif
#  - result\1578_Fe12W12.cif
#  - result\1579_Nb4V8.cif
#  - result\1580_Ag2Br2.cif
#  - result\1581_FeV3.cif
#  - result\1582_Ga2Pt2.cif
#  - result\1583_Ag3Br.cif
#  - result\1584_SnW2.cif
#  - result\1585_CuFe.cif
#  - result\1586_Cu6Pt5.cif
#  - result\1587_Nb4W4.cif
#  - result\1588_Ag2Al3.cif
#  - result\1589_CeBi.cif
#  - result\1590_PtYb.cif
#  - result\1591_Ag2Sn2.cif
#  - result\1592_BaIr5.cif
#  - result\1593_W2As2.cif
#  - result\1594_SbI.cif
#  - result\1595_Ag7Al5.cif
#  - result\1596_Ag4Ge6.cif
#  - result\1597_MoSn.cif
#  - result\1598_IrTh.cif
#  - result\1599_Eu3Sm.cif
#  - result\1600_PtRh.cif
#  - result\1601_IrV3.cif
#  - result\1602_IrPb3.cif
#  - result\1603_Au3Sr.cif
#  - result\1604_Cu16Ni4.cif
#  - result\1605_Ge8P4.cif
#  - result\1606_Ba2In4.cif
#  - result\1607_K2Na4.cif
#  - result\1608_Ag4Sn2.cif
#  - result\1609_CuRh.cif
#  - result\1610_Cu2Ga2.cif
#  - result\1611_Na4Pt2.cif
#  - result\1612_SnW3.cif
#  - result\1613_P12As17.cif
#  - result\1614_NaNi.cif
#  - result\1615_CuP3.cif
#  - result\1616_Al2K2.cif
#  - result\1617_AlSr5.cif
#  - result\1618_AlTa2.cif
#  - result\1619_Fe3V.cif
#  - result\1620_RhGe2.cif
#  - result\1621_FePb.cif
#  - result\1622_Fe44Mo2.cif
#  - result\1623_Cr8Pb4.cif
#  - result\1624_Al3Cu9.cif
#  - result\1625_In3Sm.cif
#  - result\1626_Ir6Na2.cif
#  - result\1627_Al3Sb.cif
#  - result\1628_Nb2W2.cif
#  - result\1629_PtYb.cif
#  - result\1630_BaIr.cif
#  - result\1631_Mn16W8.cif
#  - result\1632_InBr3.cif
#  - result\1633_Ba5Sn3.cif
#  - result\1634_Cu2Na.cif
#  - result\1635_Mn3V.cif
#  - result\1636_NiP3.cif
#  - result\1637_MoNb.cif
#  - result\1638_CrGa.cif
#  - result\1639_V3W.cif
#  - result\1640_Ag2Ca4.cif
#  - result\1641_Pb2As2.cif
#  - result\1642_AgI.cif
#  - result\1643_Ca3Ni.cif
#  - result\1644_FeV3.cif
#  - result\1645_Ag3In.cif
#  - result\1646_AuP.cif
#  - result\1647_PbSb.cif
#  - result\1648_Ir3Br.cif
#  - result\1649_Ag14Yb4.cif
#  - result\1650_Eu3As.cif
#  - result\1651_GaMn2.cif
#  - result\1652_Ta2Ge4.cif
#  - result\1653_AlNb.cif
#  - result\1654_RbTh.cif
#  - result\1655_WAs2.cif
#  - result\1656_Au3P.cif
#  - result\1657_SrW3.cif
#  - result\1658_Ni17Br12.cif
#  - result\1659_Cu2Fe2.cif
#  - result\1660_V6W2.cif
#  - result\1661_Na2Pt2.cif
#  - result\1662_TaGe5.cif
#  - result\1663_TaGe3.cif
#  - result\1664_NaNi.cif
#  - result\1665_Ba3Ta.cif
#  - result\1666_Ba2Fe.cif
#  - result\1667_Cs4I12.cif
#  - result\1668_Ba6As2.cif
#  - result\1669_NiPa.cif
#  - result\1670_InBr3.cif
#  - result\1671_Al2In4.cif
#  - result\1672_Al2P4.cif
#  - result\1673_AsBr2.cif
#  - result\1674_Pb2As4.cif
#  - result\1675_AgBr2.cif
#  - result\1676_Sb4Br12.cif
#  - result\1677_Fe8Ir.cif
#  - result\1678_RhYb.cif
#  - result\1679_KAs3.cif
#  - result\1680_Na4Pt2.cif
#  - result\1681_Cr3Nb.cif
#  - result\1682_AcNb.cif
#  - result\1683_WSb3.cif
#  - result\1684_FePb2.cif
#  - result\1685_Al5Rh7.cif
#  - result\1686_Ca3Ga8.cif
#  - result\1687_CrTa2.cif
#  - result\1688_VW2.cif
#  - result\1689_InRh.cif
#  - result\1690_Nb3P.cif
#  - result\1691_AuNb3.cif
#  - result\1692_As3Br.cif
#  - result\1693_AuU.cif
#  - result\1694_Ba4P8.cif
#  - result\1695_Al4Ce.cif
#  - result\1696_Cr3Na.cif
#  - result\1697_Ca5Ga3.cif
#  - result\1698_Al3Sm.cif
#  - result\1699_Ag2Ge2.cif
#  - result\1700_Fe2V2.cif
#  - result\1701_Na5Pt.cif
#  - result\1702_NaPt2.cif
#  - result\1703_Ba5Ir24.cif
#  - result\1704_P16Br4.cif
#  - result\1705_CaMn2.cif
#  - result\1706_CsIr.cif
#  - result\1707_Pd2Sn.cif
#  - result\1708_K2As2.cif
#  - result\1709_Mn5W.cif
#  - result\1710_MnV2.cif
#  - result\1711_Fe3Pb.cif
#  - result\1712_P12Br17.cif
#  - result\1713_Ba6Ga2.cif
#  - result\1714_Ba3Ga.cif
#  - result\1715_Cr3Ta.cif
#  - result\1716_Mn6W2.cif
#  - result\1717_Au4Ga.cif
#  - result\1718_Ba2Sn2.cif
#  - result\1719_Al3Ga.cif
#  - result\1720_FeIr3.cif
#  - result\1721_Al10Au20.cif
#  - result\1722_Al18In6.cif
#  - result\1723_Ag4Sn.cif
#  - result\1724_Al2Cu.cif
#  - result\1725_CrNb.cif
#  - result\1726_AuGa3.cif
#  - result\1727_MoNb3.cif
#  - result\1728_Fe3Ir.cif
#  - result\1729_AgGe.cif
#  - result\1730_Cr4Sn8.cif
#  - result\1731_CrTa.cif
#  - result\1732_PaSr.cif
#  - result\1733_FeV.cif
#  - result\1734_AgGe3.cif
#  - result\1735_Ba6Sn2.cif
#  - result\1736_CrSr3.cif
#  - result\1737_Na4Pb2.cif
#  - result\1738_IrV.cif
#  - result\1739_Ba12Ir17.cif
#  - result\1740_Al2Sr6.cif
#  - result\1741_Pt8V.cif
#  - result\1742_Al3In.cif
#  - result\1743_Na5Pt4.cif
#  - result\1744_Na2Pt2.cif
#  - result\1745_Fe2Pd2.cif
#  - result\1746_Ir2V.cif
#  - result\1747_Fe3Pb.cif
#  - result\1748_Ag4Al3.cif
#  - result\1749_Au2Ga4.cif
#  - result\1750_MnSb2.cif
#  - result\1751_Al2P2.cif
#  - result\1752_Nb2V2.cif
#  - result\1753_Ir2Pb.cif
#  - result\1754_Au3Cr.cif
#  - result\1755_V3W.cif
#  - result\1756_FePb3.cif
#  - result\1818_Ba2Pd.cif
#  - result\1819_Sn6W10.cif
#  - result\1820_In2Br4.cif
#  - result\1821_MnRh.cif
#  - result\1822_Ca3Mo.cif
#  - result\1823_Mo2W4.cif
#  - result\1824_Cu3Ga.cif
#  - result\1825_Pb2Sb6.cif
#  - result\1826_FeGa2.cif
#  - result\1827_Fe4Na.cif
#  - result\1828_Ir4Sn16.cif
#  - result\1829_FeNa3.cif
#  - result\1830_SnP3.cif
#  - result\1831_Fe2Ga2.cif
#  - result\1832_Ni4U6.cif
#  - result\1833_Ga5Br.cif
#  - result\1834_BiI.cif
#  - result\1835_Ca3Pb.cif
#  - result\1836_Mo2W2.cif
#  - result\1837_SnP.cif
#  - result\1838_SnP.cif
#  - result\1839_Al2Th2.cif
#  - result\1840_GaMo.cif
#  - result\1841_Pd2Sn8.cif
#  - result\1842_AcAl3.cif
#  - result\1843_Cu3Sn.cif
#  - result\1844_Ni2Pb2.cif
#  - result\1845_SmBi.cif
#  - result\1846_VW2.cif
#  - result\1847_Mn16W4.cif
#  - result\1848_MnNi.cif
#  - result\1849_AlSb3.cif
#  - result\1850_Au5Nb.cif
#  - result\1851_GaNa2.cif
#  - result\1852_MnW.cif
#  - result\1853_VSb.cif
#  - result\1854_Ag5Al4.cif
#  - result\1855_Ag2Ge4.cif
#  - result\1856_Cu4Pt4.cif
#  - result\1857_CuMo.cif
#  - result\1858_AlTa4.cif
#  - result\1859_Ag2Mn.cif
#  - result\1860_Nb2W4.cif
#  - result\1861_AsBr8.cif
#  - result\1862_GaMn2.cif
#  - result\1863_Fe4W2.cif
#  - result\1864_Fe5W.cif
#  - result\1865_Al2K2.cif
#  - result\1866_NiPa.cif
#  - result\1867_Cr6Sr2.cif
#  - result\1868_FeSr.cif
#  - result\1869_AlIn3.cif
#  - result\1870_Ca2Ta2.cif
#  - result\1871_FeSb.cif
#  - result\1872_Cr2As2.cif
#  - result\1873_Al2Sb2.cif
#  - result\1874_Au4Sr2.cif
#  - result\1875_Al2Sb4.cif
#  - result\1876_Ca6Cr2.cif
#  - result\1877_CuTh.cif
#  - result\1878_Ca2Rh.cif
#  - result\1879_Al2Rh.cif
#  - result\1880_Al4Ta5.cif
#  - result\1881_IrPd7.cif
#  - result\1882_AlNb2.cif
#  - result\1883_Cu4Ge2.cif
#  - result\1884_Al12K12.cif
#  - result\1885_Sb2Ge2.cif
#  - result\1886_CrSr2.cif
#  - result\1887_Fe5Pd.cif
#  - result\1888_AuGa4.cif
#  - result\1889_Ca3As.cif
#  - result\1890_CrNa3.cif
#  - result\1891_Au5Mn.cif
#  - result\1892_Cu2Ge2.cif
#  - result\1893_KPt.cif
#  - result\1894_Cr2W.cif
#  - result\1895_Ag2Al4.cif
#  - result\1896_Cr5Nb.cif
#  - result\1897_Cr5Nb.cif
#  - result\1898_Cr8Sn.cif
#  - result\1899_Cr4Rh.cif
#  - result\1900_CuK.cif
#  - result\1901_Ir2Na.cif
#  - result\1902_Ni2Sb2.cif
#  - result\1903_CrNb3.cif
#  - result\1904_In4Mn4.cif
#  - result\1905_GaNp.cif
#  - result\1906_InV.cif
#  - result\1907_VBr2.cif
#  - result\1908_CuGe3.cif
#  - result\1909_KPb.cif
#  - result\1910_KSn.cif
#  - result\1911_InTh.cif
#  - result\1912_AcV.cif
#  - result\1913_CrSn2.cif
#  - result\1914_Ba3Cu.cif
#  - result\1915_K2Sn4.cif
#  - result\1916_Cr5Rh.cif
#  - result\1917_FePt.cif
#  - result\1918_Ba3Cu.cif
#  - result\1919_NiSb3.cif
#  - result\1920_FePt3.cif
#  - result\1921_CsYb.cif
#  - result\1922_Fe2Ir.cif
#  - result\1923_InV.cif
#  - result\1924_AuNp.cif
#  - result\1925_Cu44Ni2.cif
#  - result\1926_BaAs4.cif
#  - result\1927_Cu6Pt6.cif
#  - result\1928_K2Na2.cif
#  - result\1929_Pb2Sb2.cif
#  - result\1930_W5P.cif
#  - result\1931_Cr2Nb2.cif
#  - result\1932_AgTa3.cif
#  - result\1933_Ni2Rh2.cif
#  - result\1934_BaV5.cif
#  - result\1935_Na7Pt.cif
#  - result\1936_WP3.cif
#  - result\1937_Fe8Pb4.cif
#  - result\1938_Al3Cr.cif
#  - result\1939_CaCr3.cif
#  - result\1940_Al3Cr.cif
#  - result\1941_Nb3P4.cif
#  - result\1942_Pd4Ta26.cif
#  - result\1943_Al4Ga8.cif
#  - result\1944_Th6Ge4.cif
#  - result\1945_RbU.cif
#  - result\1946_CrP.cif
#  - result\1947_MnNi.cif
#  - result\1948_Mo3Nb.cif
#  - result\1949_AlNb5.cif
#  - result\1950_Ta10Ge6.cif
#  - result\1951_Ag4Na2.cif
#  - result\1952_Ba2V2.cif
#  - result\1953_Mo16Nb8.cif
#  - result\1954_AgP3.cif
#  - result\1955_RbU.cif
#  - result\1956_Sr8W4.cif
#  - result\1957_Ir2As6.cif
#  - result\1958_Ba2Fe2.cif
#  - result\1959_Pb5Sb3.cif
#  - result\1960_AlRh2.cif
#  - result\1961_AuSr.cif
#  - result\1962_K2As2.cif
#  - result\1963_Mo4P4.cif
#  - result\1964_SrW4.cif
#  - result\1965_CuFe.cif
#  - result\1966_NaPt3.cif
#  - result\1967_Ag2In4.cif
#  - result\1968_GaSr.cif
#  - result\1969_AcAl3.cif
#  - result\1970_FePb3.cif
#  - result\1971_Ca5Cu3.cif
#  - result\1972_Ga2Pt2.cif
#  - result\1973_Fe3V.cif
#  - result\1974_BaAs.cif
#  - result\1975_Ta2Ge.cif
#  - result\1976_Ag2Na4.cif
#  - result\1977_Fe4W2.cif
#  - result\1978_InNb.cif
#  - result\1979_Fe2Pb2.cif
#  - result\1980_Ir5As.cif
#  - result\1981_As3Br.cif
#  - result\1982_Fe2V4.cif
#  - result\1983_Pb4V4.cif
#  - result\1984_CuNi5.cif
#  - result\1985_In4Br2.cif
#  - result\1986_SrI.cif
#  - result\1987_Ag3K.cif
#  - result\1988_PbGe3.cif
#  - result\1989_Ba8P.cif
#  - result\1990_CrYb.cif
#  - result\1991_AuP.cif
#  - result\1992_CaGe3.cif
#  - result\1993_K4Sn2.cif
#  - result\1994_Ga2As.cif
#  - result\1995_CuSn.cif
#  - result\1996_AgIn2.cif
#  - result\1997_BaTa2.cif
#  - result\1998_Cu5Pt5.cif
#  - result\1999_Sb3Ge5.cif
#  - result\2000_AlTa8.cif
#  - result\2001_FeMo5.cif
#  - result\2002_Sr2W2.cif
#  - result\2003_Ba2V2.cif
#  - result\2004_AsBr3.cif
#  - result\2005_Fe26Mo2.cif
#  - result\2006_CrEu.cif
#  - result\2007_W2Sb2.cif
#  - result\2008_Au2P.cif
#  - result\2009_MoNb.cif
#  - result\2010_Cr4Rh8.cif
#  - result\2011_Ba8Bi6.cif
#  - result\2012_Au8In.cif
#  - result\2013_MoV4.cif
#  - result\2014_Cr12W18.cif
#  - result\2015_AlPd.cif
#  - result\2016_Ba2Ge2.cif
#  - result\2017_Mn6Sn2.cif
#  - result\2018_Au2Mn2.cif
#  - result\2019_KNa2.cif
#  - result\2020_AlPd2.cif
#  - result\2021_CuI.cif
#  - result\2022_Cr2As.cif
#  - result\2023_Mn4Mo5.cif
#  - result\2024_K2Sn4.cif
#  - result\2025_Al2Pb4.cif
#  - result\2026_Sr8Bi6.cif
#  - result\2027_Mn2Mo4.cif
#  - result\2028_Ag3Al4.cif
#  - result\2029_GaPt5.cif
#  - result\2030_Cr8Rh4.cif
#  - result\2031_CuYb.cif
#  - result\2032_SrAs2.cif
#  - result\2033_Au2As.cif
#  - result\2034_Fe3Ga4.cif
#  - result\2035_V2Br4.cif
#  - result\2036_AgAl2.cif
#  - result\2037_Al4Pd2.cif
#  - result\2038_Nb10Ge6.cif
#  - result\2039_IrP2.cif
#  - result\2040_FePb.cif
#  - result\2041_Pt6Sn2.cif
#  - result\2042_K5As.cif
#  - result\2043_BaIr2.cif
#  - result\2044_Pd2Ta2.cif
#  - result\2045_Ba8Cu4.cif
#  - result\2046_Ba2Pd4.cif
#  - result\2047_Mo2Pb4.cif
#  - result\2048_Ca4P2.cif
#  - result\2049_Ba4Ir2.cif
#  - result\2050_Mo2Nb6.cif
#  - result\2051_GaP7.cif
#  - result\2052_InNp.cif
#  - result\2053_Pd2Rh2.cif
#  - result\2054_Pt2As.cif
#  - result\2055_Fe2As4.cif
#  - result\2056_Pd4Rh5.cif
#  - result\2057_BaFe3.cif
#  - result\2058_AcSm.cif
#  - result\2059_KNi3.cif
#  - result\2060_BaFe2.cif
#  - result\2061_AsBr3.cif
#  - result\2062_WP3.cif
#  - result\2063_Fe2Pt2.cif
#  - result\2064_Cr3Br2.cif
#  - result\2065_KNa2.cif
#  - result\2066_Fe2Ga2.cif
#  - result\2067_VBr3.cif
#  - result\2068_Ba2Ir.cif
#  - result\2069_Pt2As2.cif
#  - result\2070_In5Sn.cif
#  - result\2071_Ga12Pt12.cif
#  - result\2072_Ga2Br2.cif
#  - result\2073_BaBr2.cif
#  - result\2074_Ca2In2.cif
#  - result\2075_Ir2Mn2.cif
#  - result\2076_K5P3.cif
#  - result\2077_Sn4P.cif
#  - result\2078_V2Br2.cif
#  - result\2079_Fe2Ga4.cif
#  - result\2080_SnP.cif
#  - result\2081_Nb2Pb4.cif
#  - result\2082_BaPd.cif
#  - result\2083_PbSb.cif
#  - result\2084_Ce4Sb8.cif
#  - result\2085_Cr5P24.cif
#  - result\2086_GaRb.cif
#  - result\2087_IrNa3.cif
#  - result\2088_Nb4Pb2.cif
#  - result\2089_SnP.cif
#  - result\2090_Cu5Pt7.cif
#  - result\2091_Pb16V8.cif
#  - result\2092_K2Ge4.cif
#  - result\2093_CuPb.cif
#  - result\2094_Al3Sn.cif
#  - result\2095_GeP5.cif
#  - result\2096_CrNb3.cif
#  - result\2097_Nb2Pb.cif
#  - result\2098_Ce20Ir16.cif
#  - result\2099_Ba16Ir4.cif
#  - result\2100_Pd3Sb.cif
#  - result\2101_Mo4Nb4.cif
#  - result\2102_BaCu3.cif
#  - result\2103_BiGe.cif
#  - result\2104_As16Br4.cif
#  - result\2105_Ag8Ta4.cif
#  - result\2106_RbBi.cif
#  - result\2107_K6Ni4.cif
#  - result\2108_Ga5Pt24.cif
#  - result\2109_BaCu5.cif
#  - result\2110_RhYb.cif
#  - result\2111_Ag2P.cif
#  - result\2112_Ag6Al2.cif
#  - result\2113_PAs4.cif
#  - result\2114_Ag8P16.cif
#  - result\2115_Pd8Sb4.cif
#  - result\2116_Na2Pd.cif
#  - result\2117_Au6Nb2.cif
#  - result\2118_Ge5P3.cif
#  - result\2119_WSb.cif
#  - result\2120_Mo2Sr2.cif
#  - result\2121_AlK3.cif
#  - result\2122_CaGa4.cif
#  - result\2123_V4W2.cif
#  - result\2124_Fe6Ir2.cif
#  - result\2125_AgSn4.cif
#  - result\2126_Na2Pt2.cif
#  - result\2127_MoTa2.cif
#  - result\2128_FePd.cif
#  - result\2129_P3As.cif
#  - result\2130_Cr2Nb6.cif
#  - result\2131_Cr3Nb.cif
#  - result\2132_P5As.cif
#  - result\2133_FeMn.cif
#  - result\2134_Mn3W.cif
#  - result\2135_Sn2W2.cif
#  - result\2136_Cu3Sn.cif
#  - result\2137_IrBr3.cif
#  - result\2138_Mo3Sr.cif
#  - result\2139_Fe3Ir.cif
#  - result\2140_FePd3.cif
#  - result\2141_P8Br16.cif
#  - result\2142_K8P4.cif
#  - result\2143_VW2.cif
#  - result\2144_Al6Cu2.cif
#  - result\2145_Ag2Ge2.cif
#  - result\2146_Fe3Pd.cif
#  - result\2147_WAs3.cif
#  - result\2148_Sn2W2.cif
#  - result\2149_NaPt2.cif
#  - result\2150_MnW.cif
#  - result\2151_Ba3Ta.cif
#  - result\2152_Fe5Ir4.cif
#  - result\2153_Cr4Nb4.cif
#  - result\2154_Ba4In2.cif
#  - result\2155_AgGe2.cif
#  - result\2156_Na4Pt5.cif
#  - result\2157_InSn2.cif
#  - result\2158_Pt3V.cif
#  - result\2159_Al4Rh2.cif
#  - result\2160_SbGe3.cif
#  - result\2161_RbV.cif
#  - result\2162_CrSr2.cif
#  - result\2163_NbV2.cif
#  - result\2164_MoSr3.cif
#  - result\2165_AlSb.cif
#  - result\2166_As2Br2.cif
#  - result\2167_Al2P.cif
#  - result\2168_Pb6As18.cif
#  - result\2169_Pt2V2.cif
#  - result\2170_Al3Ta.cif
#  - result\2171_Ir2V.cif
#  - result\2172_V3W.cif
#  - result\2173_Au3P.cif
#  - result\2174_Au3Cr.cif
#  - result\2175_AgBr.cif
#  - result\2176_Ag3Sn.cif
#  - result\2177_Ag12Br12.cif
#  - result\2178_Ir4Ta8.cif
#  - result\2179_Mn2V.cif
#  - result\2180_Mn2V6.cif
#  - result\2181_Pb3As.cif
#  - result\2182_Ir3V.cif
#  - result\2183_Na6Pb2.cif
#  - result\2184_SnV.cif
#  - result\2185_Pb3Sb.cif
#  - result\2186_Ir8Pd16.cif
#  - result\2187_Fe26Pd2.cif
#  - result\2188_Al4Ta5.cif
#  - result\2189_Sb6Ge2.cif
#  - result\2190_Al2Cu4.cif
#  - result\2191_Ba4In2.cif
#  - result\2192_Ga3Na.cif
#  - result\2193_AcSb.cif
#  - result\2194_Ba2Sn4.cif
#  - result\2195_Ga8Pt16.cif
#  - result\2196_Ca4Cr2.cif
#  - result\2197_SbGe3.cif
#  - result\2198_CrNa3.cif
#  - result\2199_Al2Ta4.cif
#  - result\2200_Al3Sn.cif
#  - result\2201_TaV2.cif
#  - result\2202_Cr3Sr.cif
#  - result\2203_Ba2Sn2.cif
#  - result\2204_Al2Cu6.cif
#  - result\2205_GaMn5.cif
#  - result\2206_Mn2V.cif
#  - result\2207_Ca2Cr2.cif
#  - result\2208_As4Br4.cif
#  - result\2209_Ag2Mn2.cif
#  - result\2210_Na3Sn.cif
#  - result\2211_CuK4.cif
#  - result\2212_P2As2.cif
#  - result\2213_Ir16Pd8.cif
#  - result\2214_Mn16W4.cif
#  - result\2215_Fe4Pb8.cif
#  - result\2216_Ga2As2.cif
#  - result\2217_Ir3V.cif
#  - result\2218_Ag2Ge2.cif
#  - result\2219_KP3.cif
# ...
#  - result\4304_Mn2Rh2.cif
#  - result\4305_InPd.cif
#  - result\4306_K3V.cif
#  - result\4307_Au3Nb.cif
#  - result\4308_Al2Mn4.cif
#  - result\4309_SrBr.cif
#  - result\4310_Ca2Mo2.cif
#  - result\4311_NaTa.cif
#  - result\4312_CeSm.cif
#  - result\4313_Rh3Ta.cif
#  - result\4314_Ag2Al4.cif
#  - result\4315_Mo3V.cif
#  - result\4316_Cu3Ta.cif
#  - result\4317_Ag4Nb2.cif
#  - result\4318_AcNp.cif
#  - result\4319_Pd8Sn16.cif
#  - result\4320_TaSb3.cif
#  - result\4321_MoW2.cif
#  - result\4322_K2Sn6.cif
#  - result\4323_Au4Na2.cif
#  - result\4324_CaNb3.cif
#  - result\4325_Au4Ba2.cif
#  - result\4326_VAs7.cif
#  - result\4327_Nb3Ni.cif
#  - result\4328_AuCu.cif
#  - result\4329_Na5Pb.cif
#  - result\4330_Mo2P.cif
#  - result\4331_Rh3Ta.cif
#  - result\4332_Fe3Ge.cif
#  - result\4333_MoSr3.cif
#  - result\4334_CuSb3.cif
#  - result\4335_Fe3K.cif
#  - result\4336_In16Sn4.cif
#  - result\4337_Al12As17.cif
#  - result\4338_VP3.cif
#  - result\4339_AlCu2.cif
#  - result\4340_W2P2.cif
#  - result\4341_Mo12Rh12.cif
#  - result\4342_InSn.cif
#  - result\4343_AlK4.cif
#  - result\4344_FeNb.cif
#  - result\4345_MoP3.cif
#  - result\4346_KV3.cif
#  - result\4347_AuV.cif
#  - result\4348_Cu3Br.cif
#  - result\4349_Ir3Ta3.cif
#  - result\4350_Au2Ni2.cif
#  - result\4351_BaRh3.cif
#  - result\4352_Mn2Rh4.cif
#  - result\4353_Ba7P.cif
#  - result\4354_Fe3Bi.cif
#  - result\4355_Mo6Rh18.cif
#  - result\4356_Fe5Sb3.cif
#  - result\4357_Au2Fe2.cif
#  - result\4358_Cu4Ir.cif
#  - result\4359_MoPd.cif
#  - result\4360_Mn4W2.cif
#  - result\4361_EuNb.cif
#  - result\4362_PbGe2.cif
#  - result\4363_Al4Sr2.cif
#  - result\4364_Al3Ni.cif
#  - result\4365_Ba2W2.cif
#  - result\4366_NbV2.cif
#  - result\4367_PbGe.cif
#  - result\4368_Mo17Pd12.cif
#  - result\4369_Rh4Ge2.cif
#  - result\4370_Rh3Sb.cif
#  - result\4371_Pb6Sb18.cif
#  - result\4372_Au4Fe.cif
#  - result\4373_Ca2As6.cif
#  - result\4374_Fe3W.cif
#  - result\4375_BaAs.cif
#  - result\4376_Fe17Th2.cif
#  - result\4377_MnPd3.cif
#  - result\4378_Au2As4.cif
#  - result\4379_Pt24W5.cif
#  - result\4380_Pt2As4.cif
#  - result\4381_MoPd4.cif
#  - result\4382_Ba3Ga5.cif
#  - result\4383_V18W6.cif
#  - result\4384_AlK5.cif
#  - result\4385_Al3Cs.cif
#  - result\4386_Cu4K8.cif
#  - result\4387_AgSn3.cif
#  - result\4388_Nb2Ni4.cif
#  - result\4389_CuBr3.cif
#  - result\4390_Ni12Sr4.cif
#  - result\4391_Ga13Nb5.cif
#  - result\4392_Eu4I8.cif
#  - result\4393_V6W18.cif
#  - result\4394_In5Sb.cif
#  - result\4395_In3Mn.cif
#  - result\4396_Au2Fe4.cif
#  - result\4397_EuTa.cif
#  - result\4398_KGe3.cif
#  - result\4399_NbNi2.cif
#  - result\4400_PdTa.cif
#  - result\4401_Ag12P17.cif
#  - result\4402_BaP3.cif
#  - result\4403_Ba4Rh2.cif
#  - result\4404_Al2Cu4.cif
#  - result\4405_FeGe3.cif
#  - result\4406_Al3Ca.cif
#  - result\4407_Al17As12.cif
#  - result\4408_Cu17In12.cif
#  - result\4409_Au2Br.cif
#  - result\4410_CeCu5.cif
#  - result\4411_Rh2W2.cif
#  - result\4412_NbNi2.cif
#  - result\4413_MoW3.cif
#  - result\4414_MoW2.cif
#  - result\4415_Fe3Br.cif
#  - result\4416_AlMo.cif
#  - result\4417_Ca4Ge.cif
#  - result\4418_Na4Sr.cif
#  - result\4419_Ag4Sr2.cif
#  - result\4420_Au3P4.cif
#  - result\4421_Ir2Mn44.cif
#  - result\4422_PAs3.cif
#  - result\4423_Al2Pt2.cif
#  - result\4424_Ni3P.cif
#  - result\4425_Au2Sb2.cif
#  - result\4426_In2Nb.cif
#  - result\4427_Pd6P2.cif
#  - result\4428_FeMn5.cif
#  - result\4429_NaSb3.cif
#  - result\4430_MoYb.cif
#  - result\4431_Au2V2.cif
#  - result\4432_In11Sr3.cif
#  - result\4433_BaIn3.cif
#  - result\4434_BaW5.cif
#  - result\4435_Na2Pd6.cif
#  - result\4436_FeMn3.cif
#  - result\4437_Ga8Pt16.cif
#  - result\4438_AlFe3.cif
#  - result\4439_Mn12Sb12.cif
#  - result\4440_Fe3Pd.cif
#  - result\4441_Rh5As.cif
#  - result\4442_Mn2Ta4.cif
#  - result\4443_Nb4V.cif
#  - result\4444_Al4Ba3.cif
#  - result\4445_Ca4Nb.cif
#  - result\4446_Sn8I32.cif
#  - result\4447_V12W4.cif
#  - result\4448_Al2Nb6.cif
#  - result\4449_K3Pd.cif
#  - result\4450_Al3Sb.cif
#  - result\4451_Ca5Ge.cif
#  - result\4452_K2Pd4.cif
#  - result\4453_Au3Sn.cif
#  - result\4454_MoSr.cif
#  - result\4455_NiGe5.cif
#  - result\4456_Ga4Mn8.cif
#  - result\4457_Ca3V.cif
#  - result\4458_Fe3Nb.cif
#  - result\4459_AcMo.cif
#  - result\4460_SbP.cif
#  - result\4461_Mo8Ni4.cif
#  - result\4462_Al3Pb.cif
#  - result\4463_Mo6W2.cif
#  - result\4464_CsYb.cif
#  - result\4465_Pd2P2.cif
#  - result\4466_Ag5Pt6.cif
#  - result\4467_Ba4Fe2.cif
#  - result\4468_PdSn2.cif
#  - result\4469_GeAs.cif
#  - result\4470_Al2In.cif
#  - result\4471_Cu2Pt6.cif
#  - result\4472_MnSb2.cif
#  - result\4473_Ba4In.cif
#  - result\4474_Ni4Ta16.cif
#  - result\4475_AlNi3.cif
#  - result\4476_Ga3K.cif
#  - result\4477_Na2Pd.cif
#  - result\4478_K3Ta.cif
#  - result\4479_AlMn4.cif
#  - result\4480_Al3Ge.cif
#  - result\4481_Ba4Ir12.cif
#  - result\4482_Ba2In4.cif
#  - result\4483_Ir2Mo.cif
#  - result\4484_IrMo.cif
#  - result\4485_Na3Rh.cif
#  - result\4486_Al4Ge8.cif
#  - result\4487_Au6K2.cif
#  - result\4488_Al2V6.cif
#  - result\4489_EuNi.cif
#  - result\4490_KTa2.cif
#  - result\4491_Cu2Pb.cif
#  - result\4492_Ge4P2.cif
#  - result\4493_Na4Pd2.cif
#  - result\4494_CuGa4.cif
#  - result\4495_AgSn2.cif
#  - result\4496_UBr.cif
#  - result\4497_Fe2Sb4.cif
#  - result\4498_Mo6V2.cif
#  - result\4499_Ta3Sb.cif
#  - result\4500_IrMo2.cif
#  - result\4501_AlSb2.cif
#  - result\4502_Au3Sb.cif
#  - result\4503_Pd5Sn.cif
#  - result\4504_CaV.cif
#  - result\4505_CuIr4.cif
#  - result\4506_Ba3In.cif
#  - result\4507_AcV3.cif
#  - result\4508_Al16Mn4.cif
#  - result\4509_AuGa.cif
#  - result\4510_Ca7Ge.cif
#  - result\4511_Nb8Ni.cif
#  - result\4512_Au4V.cif
#  - result\4513_In2Mo2.cif
#  - result\4514_Al3Sn.cif
#  - result\4515_Ni24Ta5.cif
#  - result\4516_Ni2Ge4.cif
#  - result\4517_Rh3Sb.cif
#  - result\4518_AlMo3.cif
#  - result\4519_Ir2Sb2.cif
#  - result\4520_V8W4.cif
#  - result\4521_Ir8Mo22.cif
#  - result\4522_WBr.cif
#  - result\4523_Ga10V12.cif
#  - result\4524_Au3Br.cif
#  - result\4525_FePd3.cif
#  - result\4526_Fe8Ga4.cif
#  - result\4527_AuNi.cif
#  - result\4528_In16Sn4.cif
#  - result\4529_Pd2Sm2.cif
#  - result\4530_RhSb.cif
#  - result\4531_InNi2.cif
#  - result\4532_Rh3Ge.cif
#  - result\4533_Al2Fe2.cif
#  - result\4534_K5Sr24.cif
#  - result\4535_In2Mn6.cif
#  - result\4536_Ba4In5.cif
#  - result\4537_Al2Fe4.cif
#  - result\4538_Ge5As3.cif
#  - result\4539_Fe2Na6.cif
#  - result\4540_Pd4Sb2.cif
#  - result\4541_Ag2Sr.cif
#  - result\4542_KGe3.cif
#  - result\4543_Mo2Nb2.cif
#  - result\4544_Ga12Ir6.cif
#  - result\4545_Al4Mn.cif
#  - result\4546_PtRh7.cif
#  - result\4547_MoV3.cif
#  - result\4548_SbP3.cif
#  - result\4549_Al2Mn4.cif
#  - result\4550_NiTa4.cif
#  - result\4551_NbPd3.cif
#  - result\4552_Sn2Ta6.cif
#  - result\4553_InMo2.cif
#  - result\4554_NaSr.cif
#  - result\4555_Fe2V6.cif
#  - result\4556_Au8Cu16.cif
#  - result\4557_SnBr3.cif
#  - result\4558_TaSb4.cif
#  - result\4559_Al3Ba.cif
#  - result\4560_CuW3.cif
#  - result\4561_BaBr.cif
#  - result\4562_SbP2.cif
#  - result\4563_AlP.cif
#  - result\4564_CaCr.cif
#  - result\4565_CuIn7.cif
#  - result\4566_PdYb.cif
#  - result\4567_Na2Rh4.cif
#  - result\4568_Mn2Sb2.cif
#  - result\4569_Pb4P2.cif
#  - result\4570_Ba2Ge6.cif
#  - result\4571_Fe4Pb4.cif
#  - result\4572_TaP2.cif
#  - result\4573_Mn6Pd2.cif
#  - result\4574_Pt2V2.cif
#  - result\4575_Cu8P4.cif
#  - result\4576_AcPb.cif
#  - result\4577_In2Pt.cif
#  - result\4578_AlFe2.cif
#  - result\4579_Pd2V2.cif
#  - result\4580_Au10Ni6.cif
#  - result\4581_Ca3Nb.cif
#  - result\4582_Pt4V12.cif
#  - result\4583_Na2Pt2.cif
#  - result\4584_Ag4Pt7.cif
#  - result\4585_CsIr.cif
#  - result\4586_Ni3P.cif
#  - result\4587_InMo8.cif
#  - result\4588_Ag3Ni.cif
#  - result\4589_AuPb3.cif
#  - result\4590_In2Br2.cif
#  - result\4591_Mo2Sn.cif
#  - result\4592_In3Mn.cif
#  - result\4593_K2Pd6.cif
#  - result\4594_Ag4Ir2.cif
#  - result\4595_MnW3.cif
#  - result\4596_KGe.cif
#  - result\4597_NiGe4.cif
#  - result\4598_Ni3Rh3.cif
#  - result\4599_AuNi3.cif
#  - result\4600_Sr8Br16.cif
#  - result\4601_K3P.cif
#  - result\4602_Mo8W.cif
#  - result\4603_Cu2In6.cif
#  - result\4604_Ba2As4.cif
#  - result\4605_Cu6Ir2.cif
#  - result\4606_MoNb5.cif
#  - result\4607_In4Mo.cif
#  - result\4608_Mn2Rh.cif
#  - result\4609_Ni2P2.cif
#  - result\4610_BaNb3.cif
#  - result\4611_Sn3V.cif
#  - result\4612_IrK.cif
#  - result\4613_In3Mo5.cif
#  - result\4614_Al2K4.cif
#  - result\4615_Nb2As2.cif
#  - result\4616_Pt3V5.cif
#  - result\4617_PbGe2.cif
#  - result\4618_PtBi3.cif
#  - result\4619_Ba2In4.cif
#  - result\4620_UBi.cif
#  - result\4621_NaP3.cif
#  - result\4622_Na3Pd.cif
#  - result\4623_AgGa5.cif
#  - result\4624_Sn4W2.cif
#  - result\4625_Ba4P.cif
#  - result\4626_AgAu3.cif
#  - result\4627_Cu2Mn2.cif
#  - result\4628_Pt16Rb8.cif
#  - result\4629_Pd3V.cif
#  - result\4630_Nb2V4.cif
#  - result\4631_V2Ge2.cif
#  - result\4632_Al5K.cif
#  - result\4633_Au5Sb.cif
#  - result\4634_Cu16Ir8.cif
#  - result\4635_Fe6Ta4.cif
#  - result\4636_Ag6Pt6.cif
#  - result\4637_Na4P.cif
#  - result\4638_PdSr.cif
#  - result\4639_CrNi.cif
#  - result\4640_Fe4As2.cif
#  - result\4641_CuV3.cif
#  - result\4642_AgSr.cif
#  - result\4643_PdV3.cif
#  - result\4644_PbPt3.cif
#  - result\4645_Na2P2.cif
#  - result\4701_Fe8Ta4.cif
#  - result\4702_AlPb8.cif
#  - result\4703_Sr4Br2.cif
#  - result\4704_Pa3Bi.cif
#  - result\4710_Mn2V2.cif
#  - result\4711_Fe3Mn.cif
#  - result\4712_Fe6Nb2.cif
#  - result\4713_Al2Ba4.cif
#  - result\4714_MoNp.cif
#  - result\4715_CeU3.cif
#  - result\4716_SrBi.cif
#  - result\4717_PaP.cif
#  - result\4718_AgIn3.cif
#  - result\4719_Ir10Rh6.cif
#  - result\4720_Cr6Pt2.cif
#  - result\4721_UP.cif
#  - result\4722_Ba2Pb.cif
#  - result\4723_PaGe.cif
#  - result\4724_Cu3W.cif
#  - result\4725_TaP5.cif
#  - result\4726_AlK.cif
#  - result\4727_FeNa3.cif
#  - result\4728_Au2Nb3.cif
#  - result\4729_Mn2V2.cif
#  - result\4730_Au3Ba5.cif
#  - result\4731_MoBr3.cif
#  - result\4732_MoSn4.cif
#  - result\4733_K6Br18.cif
#  - result\4734_Fe4Pd6.cif
#  - result\4735_V26W2.cif
#  - result\4736_Rh6W2.cif
#  - result\4737_Fe2Nb4.cif
#  - result\4738_Pd2Sb.cif
#  - result\4739_Ir16Mo14.cif
#  - result\4740_Mn2Na4.cif
#  - result\4741_Ni2Ge4.cif
#  - result\4742_Ge5As.cif
#  - result\4743_CaW2.cif
#  - result\4744_AuW8.cif
#  - result\4745_Ba5Pb.cif
#  - result\4746_Au2Ni2.cif
#  - result\4747_BaW3.cif
#  - result\4748_AcTh3.cif
#  - result\4749_K6Rh2.cif
#  - result\4750_Al2Pd6.cif
#  - result\4751_Mn4W2.cif
#  - result\4752_CaAs3.cif
#  - result\4753_Cu4Ta4.cif
#  - result\4754_Au2Ba6.cif
#  - result\4755_AuAs3.cif
#  - result\4756_K2Sn2.cif
#  - result\4757_InBr.cif
#  - result\4758_Mo4Nb12.cif
#  - result\4759_Au4Ni8.cif
#  - result\4760_Mn4Ta5.cif
#  - result\4761_Fe4Ga4.cif
#  - result\4762_Fe3Sb.cif
#  - result\4763_InMo5.cif
#  - result\4764_PtSm.cif
#  - result\4765_Mo3W.cif
#  - result\4766_Au2Mn2.cif
#  - result\4767_Sn4W8.cif
#  - result\4768_Pb6P2.cif
#  - result\4769_Sr2Br6.cif
#  - result\4770_Cu8Ta4.cif
#  - result\4771_EuSb.cif
#  - result\4772_Ba4Ta2.cif
#  - result\4773_NaPt.cif
#  - result\4774_PtGe.cif
#  - result\4775_Mo4P8.cif
#  - result\4776_Ni2Ge6.cif
#  - result\4777_Al4Ba.cif
#  - result\4778_MnRh5.cif
#  - result\4779_MoW.cif
#  - result\4780_Pb4P.cif
#  - result\4781_NpTa.cif
#  - result\4782_Sr4Br.cif
#  - result\4783_Ag24Al5.cif
#  - result\4784_Ni4Rh2.cif
#  - result\4785_Mo2Nb.cif
#  - result\4786_NpPa.cif
#  - result\4787_Cu2Ni2.cif
#  - result\4788_Mo2Pb2.cif
#  - result\4789_Na2Pb.cif
#  - result\4790_Ba5W.cif
#  - result\4791_NaP3.cif
#  - result\4792_Ni2Yb2.cif
#  - result\4793_AlTa.cif
#  - result\4794_EuNi.cif
#  - result\4795_FeW7.cif
#  - result\4796_Ni3P.cif
#  - result\4797_Pt3V.cif
#  - result\4798_SnBr4.cif
#  - result\4799_Ba3In3.cif
#  - result\4800_Nb3Br5.cif
#  - result\4801_Ir2Rh4.cif
#  - result\4802_K4Pd2.cif
#  - result\4803_Mo5W.cif
#  - result\4804_Ca2P.cif
#  - result\4805_Sn2Br4.cif
#  - result\4806_Rh2As.cif
#  - result\4807_GaIn.cif
#  - result\4808_Nb5Br3.cif
#  - result\4809_Mn6W2.cif
#  - result\4810_CeNi3.cif
#  - result\4811_CuIn3.cif
#  - result\4812_Ba3W.cif
#  - result\4813_Ca3Nb.cif
#  - result\4814_Pd4V4.cif
#  - result\4815_Nb4Ni2.cif
#  - result\4816_Ba2Sb2.cif
#  - result\4817_AgNb3.cif
#  - result\4818_AgW2.cif
#  - result\4819_NaSr.cif
#  - result\4820_V2W.cif
#  - result\4821_Ag3Nb3.cif
#  - result\4822_Al6Br2.cif
#  - result\4823_CuSb3.cif
#  - result\4824_Al6Mn2.cif
#  - result\4825_Cu2Sb2.cif
#  - result\4826_Au2V2.cif
#  - result\4827_Mo2Pd.cif
#  - result\4828_AuV.cif
#  - result\4829_Fe2Ta6.cif
#  - result\4830_Fe2As.cif
#  - result\4831_Al4V2.cif
#  - result\4832_Pt2Sb2.cif
#  - result\4833_Mn2Nb.cif
#  - result\4834_In3V.cif
#  - result\4835_CaGa.cif
#  - result\4836_NiSr.cif
#  - result\4837_Ag6Fe2.cif
#  - result\4838_FeU3.cif
#  - result\4839_Fe2Sb6.cif
#  - result\4840_Al4Pd4.cif
#  - result\4841_Mo2Sr2.cif
#  - result\4842_CaCu.cif
#  - result\4843_CrSm.cif
#  - result\4844_CuIn7.cif
#  - result\4845_VP4.cif
#  - result\4846_Al3Mn.cif
#  - result\4847_Nb10Ni6.cif
#  - result\4848_AgSn8.cif
#  - result\4849_Sn4Br4.cif
#  - result\4850_Mn3Pd.cif
#  - result\4851_NbRh3.cif
#  - result\4852_GaMn2.cif
#  - result\4853_Au3V.cif
#  - result\4854_Ag4Pt7.cif
#  - result\4855_K3P4.cif
#  - result\4856_Al4Ni4.cif
#  - result\4857_Ag2P2.cif
#  - result\4858_TaW3.cif
#  - result\4859_Mo3Rh.cif
#  - result\4860_KMo3.cif
#  - result\4861_NbNi2.cif
#  - result\4862_FeGe.cif
#  - result\4863_AlBa2.cif
#  - result\4864_K2Mo.cif
#  - result\4865_Ag2Ga.cif
#  - result\4866_Pt2V2.cif
#  - result\4867_Fe2Ir.cif
#  - result\4868_AgSr3.cif
#  - result\4869_AuSn7.cif
#  - result\4870_AlV.cif
#  - result\4871_AuV.cif
#  - result\4872_K6Ge18.cif
#  - result\4873_Ba4V2.cif
#  - result\4874_Ga5Nb3.cif
#  - result\4875_Sn2W4.cif
#  - result\4876_GeAs.cif
#  - result\4877_Al2Ni2.cif
#  - result\4878_EuTh.cif
#  - result\4879_InPb2.cif
#  - result\4880_AlBa3.cif
#  - result\4881_Pd8V4.cif
#  - result\4882_Cu4Ge4.cif
#  - result\4883_Mo6Rh2.cif
#  - result\4884_PdV3.cif
#  - result\4885_AsI.cif
#  - result\4886_Al2Br2.cif
#  - result\4887_CsCu.cif
#  - result\4888_Pt4Rb16.cif
#  - result\4889_Au12Sb4.cif
#  - result\4890_Ga4Nb6.cif
#  - result\4891_Nb4Sr2.cif
#  - result\4892_Mn2Rh4.cif
#  - result\4893_FeNi.cif
#  - result\4894_AgSr.cif
#  - result\4895_AgSr.cif
#  - result\4896_Al5As24.cif
#  - result\4897_CaSn.cif
#  - result\4898_Al2Au.cif
#  - result\4899_InW3.cif
#  - result\4900_Ca2Sr.cif
#  - result\4901_Rh2Sb4.cif
#  - result\4902_AgGa5.cif
#  - result\4903_Mn3Sr.cif
#  - result\4904_Pt2W2.cif
#  - result\4905_Cu4K16.cif
#  - result\4906_Rh6Sb4.cif
#  - result\4907_Rh2Ta4.cif
#  - result\4908_Mo2Ta2.cif
#  - result\4909_InMn5.cif
#  - result\4910_AgGa5.cif
#  - result\4911_NiPd3.cif
#  - result\4912_NaBr3.cif
#  - result\4913_Na3Rh.cif
#  - result\4914_Fe2As.cif
#  - result\4915_Cu2Rh6.cif
#  - result\4916_SbP3.cif
#  - result\4917_In2Pd2.cif
#  - result\4918_PI3.cif
#  - result\4919_EuGa.cif
#  - result\4920_PbAs3.cif
#  - result\4921_NaP.cif
#  - result\4922_NbAs3.cif
#  - result\4923_Rh6W4.cif
#  - result\4924_Al2Sb4.cif
#  - result\4925_AuPa.cif
#  - result\4926_PdU.cif
#  - result\4927_Ag3Pb.cif
#  - result\4928_Ba2Mn2.cif
#  - result\4929_Ag3Au.cif
#  - result\4930_Cu4Yb2.cif
#  - result\4931_Pb4As3.cif
#  - result\4932_Al4Bi2.cif
#  - result\4933_FeNb.cif
#  - result\4934_Mn3Pb.cif
#  - result\4935_InPt.cif
#  - result\4936_Pb3As.cif
#  - result\4937_Fe2As.cif
#  - result\4938_Ni2Sb4.cif
#  - result\4939_Ir4Nb8.cif
#  - result\4940_IrW4.cif
#  - result\4941_YbGe.cif
#  - result\4942_PtW2.cif
#  - result\4943_InK.cif
#  - result\4944_PBr3.cif
#  - result\4945_Al3Br.cif
#  - result\4946_Rh2W2.cif
#  - result\4947_Pd2W4.cif
#  - result\4948_SmW.cif
#  - result\4949_AgCu8.cif
#  - result\4950_CuMn2.cif
#  - result\4951_Pd3Rb.cif
#  - result\4952_Pd2W.cif
#  - result\4953_SnSb.cif
#  - result\4954_Ni2V4.cif
#  - result\4955_Fe2Br2.cif
#  - result\4956_AlSb2.cif
#  - result\4957_IrTa5.cif
#  - result\4958_Ba2Ge2.cif
#  - result\4959_GaNa3.cif
#  - result\4960_Sn6Sb2.cif
#  - result\4961_IrNa3.cif
#  - result\4962_Ge2P4.cif
#  - result\4963_Cu8In.cif
#  - result\4964_Cu3Na5.cif
#  - result\4965_Fe4Pd2.cif
#  - result\4966_PdU.cif
#  - result\4967_PtYb.cif
#  - result\4968_Al4Pt2.cif
#  - result\4969_PtP3.cif
#  - result\4970_PdAs.cif
#  - result\4971_Ni2Sb4.cif
#  - result\4972_Fe4Mn4.cif
#  - result\4973_Pb4V4.cif
#  - result\4974_SmYb.cif
#  - result\4975_AlRb.cif
#  - result\4976_Rh3Ta.cif
#  - result\4977_Fe2Ir2.cif
#  - result\4978_Sn3Br.cif
#  - result\4979_RhSb.cif
#  - result\4980_Rh6P4.cif
#  - result\4981_Ag2Br6.cif
#  - result\4982_Ga3Nb.cif
#  - result\4983_Ba4Ca2.cif
#  - result\4984_Na4Pd.cif
#  - result\4985_Cu5Mn.cif
#  - result\4986_Pb2Sr2.cif
#  - result\4987_In3W.cif
#  - result\4988_FeYb3.cif
#  - result\4989_Cu12Ge12.cif
#  - result\4990_Au2Nb4.cif
#  - result\4991_Cu2W.cif
#  - result\4992_Ag4Al2.cif
#  - result\4993_Ag4Al2.cif
#  - result\4994_Ba2Ir2.cif
#  - result\4995_Au2Sb2.cif
#  - result\4996_Al2In2.cif
#  - result\4997_Ag3Br.cif
#  - result\4998_Al16Ge8.cif
#  - result\4999_Pt2Th2.cif
#  - result\5000_Ga5Sr.cif
#  - result\5001_MoSr3.cif
